# %% [markdown]
# <a href="https://colab.research.google.com/github/HibaBargaoui/Project-2/blob/main/Project_2_Part_4_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras import metrics

# %% [markdown]
# **Load Data**

# %%
df = pd.read_csv('/content/MyDrive/MyDrive/Project_Data/supply_train.csv')
df.head()
# Out:
#    Unnamed: 0 Ware_house_ID WH_Manager_ID Location_type WH_capacity_size  \
# 0           0     WH_100000     EID_50000         Urban            Small
# 1           1     WH_100001     EID_50001         Rural            Large
# 2           2     WH_100002     EID_50002         Rural              Mid
# 3           3     WH_100003     EID_50003         Rural              Mid
# 4           4     WH_100004     EID_50004         Rural            Large
#
#     zone WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# 0   West           Zone 6                   3                    1
# 1  North           Zone 5                   0                    0
# 2  South           Zone 2                   1                    0
# 3  North           Zone 3                   7                    4
# 4  North           Zone 5                   3                    1
#
#    Competitor_in_mkt  ...  electric_supply dist_from_hub  workers_num  \
# 0                  2  ...                1            91         29.0
# 1                  4  ...                1           210         31.0
# 2                  4  ...                0           161         37.0
# 3                  2  ...                0           103         21.0
# 4                  2  ...                1           112         25.0
#
#    wh_est_year  storage_issue_reported_l3m  temp_reg_mach  \
# 0          NaN                          13              0
# 1          NaN                           4              0
# 2          NaN                          17              0
# 3          NaN                          17              1
# 4       2009.0                          18              0
#
#    approved_wh_govt_certificate  wh_breakdown_l3m  govt_check_l3m  \
# 0                             A                 5              15
# 1                             A                 3              17
# 2                             A                 6              22
# 3                            A+                 3              27
# 4                             C                 6              24
#
#    product_wg_ton
# 0           17115
# 1            5074
# 2           23137
# 3           22115
# 4           24071
#
# [5 rows x 25 columns]

# %% [markdown]
# **Delete unnecessary columns**

# %%
df = df.drop(columns = ['Ware_house_ID', 'WH_Manager_ID'])
df.head()
# Out:
#    Unnamed: 0 Location_type WH_capacity_size   zone WH_regional_zone  \
# 0           0         Urban            Small   West           Zone 6
# 1           1         Rural            Large  North           Zone 5
# 2           2         Rural              Mid  South           Zone 2
# 3           3         Rural              Mid  North           Zone 3
# 4           4         Rural            Large  North           Zone 5
#
#    num_refill_req_l3m  transport_issue_l1y  Competitor_in_mkt  \
# 0                   3                    1                  2
# 1                   0                    0                  4
# 2                   1                    0                  4
# 3                   7                    4                  2
# 4                   3                    1                  2
#
#    retail_shop_num  wh_owner_type  ...  electric_supply  dist_from_hub  \
# 0             4651         Rented  ...                1             91
# 1             6217  Company Owned  ...                1            210
# 2             4306  Company Owned  ...                0            161
# 3             6000         Rented  ...                0            103
# 4             4740  Company Owned  ...                1            112
#
#    workers_num  wh_est_year  storage_issue_reported_l3m  temp_reg_mach  \
# 0         29.0          NaN                          13              0
# 1         31.0          NaN                           4              0
# 2         37.0          NaN                          17              0
# 3         21.0          NaN                          17              1
# 4         25.0       2009.0                          18              0
#
#    approved_wh_govt_certificate  wh_breakdown_l3m  govt_check_l3m  \
# 0                             A                 5              15
# 1                             A                 3              17
# 2                             A                 6              22
# 3                            A+                 3              27
# 4                             C                 6              24
#
#   product_wg_ton
# 0          17115
# 1           5074
# 2          23137
# 3          22115
# 4          24071
#
# [5 rows x 23 columns]

# %% [markdown]
# **Delete duplicate rows**

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated rows.

# %% [markdown]
# **Identify missing values**

# %%
df.isna().sum()
# Out:
# Unnamed: 0                         0
# Location_type                      0
# WH_capacity_size                   0
# zone                               0
# WH_regional_zone                   0
# num_refill_req_l3m                 0
# transport_issue_l1y                0
# Competitor_in_mkt                  0
# retail_shop_num                    0
# wh_owner_type                      0
# distributor_num                    0
# flood_impacted                     0
# flood_proof                        0
# electric_supply                    0
# dist_from_hub                      0
# workers_num                      667
# wh_est_year                     7860
# storage_issue_reported_l3m         0
# temp_reg_mach                      0
# approved_wh_govt_certificate     599
# wh_breakdown_l3m                   0
# govt_check_l3m                     0
# product_wg_ton                     0
# dtype: int64

# %% [markdown]
# ### Data preprocessing

# %%
# Set the feature (X) and the target (y)
X = df.drop(columns='product_wg_ton')
y = df['product_wg_ton']

# %%
# train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Select columns
num_cols = make_column_selector(dtype_include='number')
cat_cols = make_column_selector(dtype_include='object')

# %%
# Instantiate the scaler, onehotencoder and imputer
scaler = StandardScaler()
ohe = OneHotEncoder()
impute_median = SimpleImputer(strategy='median')
impute_freq = SimpleImputer(strategy='most_frequent')

# %%
# Make pipeline
num_pipe = make_pipeline(impute_median, scaler)
cat_pipe = make_pipeline(impute_freq, ohe)

# %%
# Set tuple
num_tup = (num_pipe, num_cols)
cat_tup = (cat_pipe, cat_cols)

# %%
# Instantiate the column transformer
col_tf = make_column_transformer(num_tup, cat_tup, remainder='passthrough')

# %%
# Fit the column transformer on the X_train
X_train_processed = col_tf.fit(X_train)

# %%
# Extract the feature names from one hot encoder
cat_feature_names = col_tf.named_transformers_['pipeline-2']\
                              .named_steps['onehotencoder']\
                              .get_feature_names_out(cat_cols(X_train))

cat_feature_names
# Out:
# array(['Location_type_Rural', 'Location_type_Urban',
#        'WH_capacity_size_Large', 'WH_capacity_size_Mid',
#        'WH_capacity_size_Small', 'zone_East', 'zone_North', 'zone_South',
#        'zone_West', 'WH_regional_zone_Zone 1', 'WH_regional_zone_Zone 2',
#        'WH_regional_zone_Zone 3', 'WH_regional_zone_Zone 4',
#        'WH_regional_zone_Zone 5', 'WH_regional_zone_Zone 6',
#        'wh_owner_type_Company Owned', 'wh_owner_type_Rented',
#        'approved_wh_govt_certificate_A',
#        'approved_wh_govt_certificate_A+',
#        'approved_wh_govt_certificate_B',
#        'approved_wh_govt_certificate_B+',
#        'approved_wh_govt_certificate_C'], dtype=object)

# %%
# Get final col names which are num features + cat features
final_cols = num_cols(X_train) + list(cat_feature_names)
final_cols
# Out:
# ['Unnamed: 0',
#  'num_refill_req_l3m',
#  'transport_issue_l1y',
#  'Competitor_in_mkt',
#  'retail_shop_num',
#  'distributor_num',
#  'flood_impacted',
#  'flood_proof',
#  'electric_supply',
#  'dist_from_hub',
#  'workers_num',
#  'wh_est_year',
#  'storage_issue_reported_l3m',
#  'temp_reg_mach',
#  'wh_breakdown_l3m',
#  'govt_check_l3m',
#  'Location_type_Rural',
#  'Location_type_Urban',
#  'WH_capacity_size_Large',
#  'WH_capacity_size_Mid',
#  'WH_capacity_size_Small',
#  'zone_East',
#  'zone_North',
#  'zone_South',
#  'zone_West',
#  'WH_regional_zone_Zone 1',
#  'WH_regional_zone_Zone 2',
#  'WH_regional_zone_Zone 3',
#  'WH_regional_zone_Zone 4',
#  'WH_regional_zone_Zone 5',
#  'WH_regional_zone_Zone 6',
#  'wh_owner_type_Company Owned',
#  'wh_owner_type_Rented',
#  'approved_wh_govt_certificate_A',
#  'approved_wh_govt_certificate_A+',
#  'approved_wh_govt_certificate_B',
#  'approved_wh_govt_certificate_B+',
#  'approved_wh_govt_certificate_C']

# %%
# Transform the X_train and the X_test
X_train_tf = col_tf.transform(X_train)
X_test_tf = col_tf.transform(X_test)

# %%
# Change the X_train and X_test transformed columns to a dataframe
X_train_output = pd.DataFrame(X_train_tf, columns = final_cols)
X_test_output = pd.DataFrame(X_test_tf, columns = final_cols)

# %% [markdown]
# ### Modeling

# %% [markdown]
# **Evaluation function**

# %%
def eval_model(true, pred):
  mae = mean_absolute_error(true, pred)
  mse = mean_squared_error(true, pred)
  rmse = np.sqrt(mse)
  r2 = r2_score(true, pred)
  # print the results
  print(f' MAE: {mae:.2f} \n MSE: {mse:.2f} \n RMSE: {rmse:.2f} \n R2_score: {r2:.2f}')

# %% [markdown]
# **Linear Regression**

# %%
# Instantiate the linear regression model
lr = LinearRegression()

# %%
# Fit the linear regression model on the training data
lr.fit(X_train_tf, y_train)
# Out:
# LinearRegression()

# %%
# Get predictions
lr_train_preds = lr.predict(X_train_tf)
lr_test_preds = lr.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, lr_train_preds)
print('\nTesting Data')
eval_model(y_test , lr_test_preds)
# Out:
# Training Data
#  MAE: 1003.94
#  MSE: 1867892.65
#  RMSE: 1366.71
#  R2_score: 0.99
#
# Testing Data
#  MAE: 1031.44
#  MSE: 2081728.30
#  RMSE: 1442.82
#  R2_score: 0.98

# %% [markdown]
# **Decision Tree Regressor**

# %%
# Instantiate the Decision Tree Regressor
dt = DecisionTreeRegressor(random_state=42)

# %%
# Fit the Decision Tree Regressor on the training data
dt.fit(X_train_tf, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# Get predictions
dt_train_preds = dt.predict(X_train_tf)
dt_test_preds = dt.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, dt_train_preds)
print('\nTesting Data')
eval_model(y_test , dt_test_preds)
# Out:
# Training Data
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-acda783ae347> in <cell line: 3>()
#       1 # Evaluate the results
#       2 print('Training Data')
# ----> 3 eval_model(y_train, dt_train_preds)
#       4 print('\nTesting Data')
#       5 eval_model(y_test , dt_test_preds)
#
# <ipython-input-33-fd0b2b219bef> in eval_model(true, pred)
#       3   mse = mean_squared_error(true, pred)
#       4   rmse = np.sqrt(mse)
# ----> 5   r2 = r2_score(true, pred)
#       6   # print the results
#       7   print(f' MAE: {mae:.2f} \n MSE: {mse:.2f} \n RMSE: {rmse:.2f} \n R2_score: {r2:.2f}')
#
# <ipython-input-90-cf9975493958> in r2_score(y_true, y_pred)
#       3 def r2_score(y_true, y_pred):
#       4     SS_res =  K.sum(K.square(y_true - y_pred))
# ----> 5     SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
#       6     return (1 - SS_res / (SS_tot + K.epsilon()))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in mean(x, axis, keepdims)
#    2919         A tensor with the mean of elements of `x`.
#    2920     """
# -> 2921     if x.dtype.base_dtype == tf.bool:
#    2922         x = tf.cast(x, floatx())
#    2923     return tf.reduce_mean(x, axis, keepdims)
#
# AttributeError: 'numpy.dtype[int64]' object has no attribute 'base_dtype'

# %% [markdown]
# **Tunned Decision Tree Regressor**

# %%
# Instantiate the Tunned Decision Tree Regressor
tdt = DecisionTreeRegressor()

# %%
# Get parameters
tdt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
# Set the parameters grid
param_grid={'max_depth':[1,2,3],
            'min_samples_leaf':[5,10,20],
            'min_samples_split':[5,10,100]}

# %%
# Instantiate the GridSearchCV
tdt_gs = GridSearchCV(tdt, param_grid)

# %%
# Fit the GridSearchCV on the training data
tdt_gs.fit(X_train_tf, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [1, 2, 3],
#                          'min_samples_leaf': [5, 10, 20],
#                          'min_samples_split': [5, 10, 100]})

# %%
tdt_gs.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 5}

# %%
# Get the best Tunned Decision Tree Regressor
best_tdt = tdt_gs.best_estimator_

# %%
# Fit the best Tunned Decision Tree Regressor on training data
best_tdt.fit(X_train_tf, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=5)

# %%
# Get predictions
best_tdt_train_preds = best_tdt.predict(X_train_tf)
best_tdt_test_preds = best_tdt.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, best_tdt_train_preds)
print('\nTesting Data')
eval_model(y_test , best_tdt_test_preds)
# Out:
# Training Data
#  MAE: 1717.67
#  MSE: 4893804.15
#  RMSE: 2212.19
#  R2_score: 0.96
#
# Testing Data
#  MAE: 1718.15
#  MSE: 4940992.49
#  RMSE: 2222.83
#  R2_score: 0.96

# %% [markdown]
# **Random Forest Regressor**

# %%
# Instantiate the Random Forest Regressor
rf = RandomForestRegressor(random_state=42)

# %%
# Fit the Random Forest Regressor on training data
rf.fit(X_train_tf, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Get predictions
rf_train_preds = rf.predict(X_train_tf)
rf_test_preds = rf.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, rf_train_preds)
print('\nTesting Data')
eval_model(y_test , rf_test_preds)
# Out:
# Training Data
#  MAE: 253.12
#  MSE: 118606.93
#  RMSE: 344.39
#  R2_score: 1.00
#
# Testing Data
#  MAE: 681.78
#  MSE: 873980.30
#  RMSE: 934.87
#  R2_score: 0.99

# %% [markdown]
# **Tunned Random Forest Regressor**

# %%
# Instantiate the Tunned Decision Tree Regressor
trf = RandomForestRegressor()

# %%
# Get parameters
trf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Set the parameters grid
param_grid={'max_depth':[3,5,10],
            'n_estimators':[50,100,200]}

# %%
# Instantiate the GridSearchCV
trf_gs = GridSearchCV(trf, param_grid)

# %%
# Fit the GridSearchCV on the training data
trf_gs.fit(X_train_tf, y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [1, 2, 3],
#                          'min_samples_leaf': [5, 10, 20],
#                          'min_samples_split': [5, 10, 100]})

# %%
trf_gs.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 100}

# %%
# Get the best Tunned Decision Tree Regressor
best_trf = trf_gs.best_estimator_

# %%
# Fit the best Tunned Decision Tree Regressor on training data
best_trf.fit(X_train_tf, y_train)
# Out:
# RandomForestRegressor(max_depth=3, min_samples_leaf=5, min_samples_split=100)

# %%
# Get predictions
best_trf_train_preds = best_trf.predict(X_train_tf)
best_trf_test_preds = best_trf.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, best_trf_train_preds)
print('\nTesting Data')
eval_model(y_test , best_trf_test_preds)
# Out:
# Training Data
#  MAE: 1608.86
#  MSE: 4287933.00
#  RMSE: 2070.73
#  R2_score: 0.97
#
# Testing Data
#  MAE: 1605.18
#  MSE: 4327545.83
#  RMSE: 2080.28
#  R2_score: 0.97

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
# Instantiate the Gradient Boosting Regressor
gbr = GradientBoostingRegressor()

# %%
# Fit the the Gradient Boosting Regressor on training data
gbr.fit(X_train_tf, y_train)
# Out:
# GradientBoostingRegressor()

# %%
# Get predictions
gbr_train_preds = gbr.predict(X_train_tf)
gbr_test_preds = gbr.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, gbr_train_preds)
print('\nTesting Data')
eval_model(y_test , gbr_test_preds)
# Out:
# Training Data
#  MAE: 666.95
#  MSE: 774189.07
#  RMSE: 879.88
#  R2_score: 0.99
#
# Testing Data
#  MAE: 684.71
#  MSE: 856522.46
#  RMSE: 925.48
#  R2_score: 0.99

# %% [markdown]
# **XGBoost Regressor**

# %%
# Instantiate the Gradient Boosting Regressor
xgb = XGBRegressor()

# %%
# Fit the the Gradient Boosting Regressor on training data
xgb.fit(X_train_tf, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Get predictions
xgb_train_preds = xgb.predict(X_train_tf)
xgb_test_preds = xgb.predict(X_test_tf)

# %%
# Evaluate the results
print('Training Data')
eval_model(y_train, xgb_train_preds)
print('\nTesting Data')
eval_model(y_test , xgb_test_preds)
# Out:
# Training Data
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-7492c0d687bb> in <cell line: 3>()
#       1 # Evaluate the results
#       2 print('Training Data')
# ----> 3 eval_model(y_train, xgb_train_preds)
#       4 print('\nTesting Data')
#       5 eval_model(y_test , xgb_test_preds)
#
# <ipython-input-33-fd0b2b219bef> in eval_model(true, pred)
#       3   mse = mean_squared_error(true, pred)
#       4   rmse = np.sqrt(mse)
# ----> 5   r2 = r2_score(true, pred)
#       6   # print the results
#       7   print(f' MAE: {mae:.2f} \n MSE: {mse:.2f} \n RMSE: {rmse:.2f} \n R2_score: {r2:.2f}')
#
# <ipython-input-90-cf9975493958> in r2_score(y_true, y_pred)
#       3 def r2_score(y_true, y_pred):
#       4     SS_res =  K.sum(K.square(y_true - y_pred))
# ----> 5     SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
#       6     return (1 - SS_res / (SS_tot + K.epsilon()))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in mean(x, axis, keepdims)
#    2919         A tensor with the mean of elements of `x`.
#    2920     """
# -> 2921     if x.dtype.base_dtype == tf.bool:
#    2922         x = tf.cast(x, floatx())
#    2923     return tf.reduce_mean(x, axis, keepdims)
#
# AttributeError: 'numpy.dtype[int64]' object has no attribute 'base_dtype'

# %% [markdown]
# **Neural Network**

# %%
from keras import backend as K

def r2_score(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return (1 - SS_res / (SS_tot + K.epsilon()))

# %%
# Model Sequential
model_1 = Sequential()

# Hidden layers
model_1.add(Dense(37, input_dim = X_train_tf.shape[1], activation='relu'))
model_1.add(Dense(25, activation='relu'))
model_1.add(Dense(10, activation='relu'))

# Output layer
model_1.add(Dense(1, activation='linear'))

# Compile the model
model_1.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.RootMeanSquaredError()])

# Fit the model
history = model_1.fit(X_train_tf, y_train,
                    validation_data = (X_test_tf, y_test),
                    epochs = 100,
                    batch_size = 32)
# Out:
# Epoch 1/100
# 390/390 [==============================] - 2s 3ms/step - loss: 544733952.0000 - mean_absolute_error: 20326.2520 - root_mean_squared_error: 23339.5371 - val_loss: 236201120.0000 - val_mean_absolute_error: 12575.6885 - val_root_mean_squared_error: 15368.8359
# Epoch 2/100
# 390/390 [==============================] - 1s 2ms/step - loss: 61947556.0000 - mean_absolute_error: 5895.6494 - root_mean_squared_error: 7870.6768 - val_loss: 29810658.0000 - val_mean_absolute_error: 4339.2275 - val_root_mean_squared_error: 5459.9136
# Epoch 3/100
# 390/390 [==============================] - 1s 3ms/step - loss: 23517728.0000 - mean_absolute_error: 3839.8481 - root_mean_squared_error: 4849.5078 - val_loss: 18131468.0000 - val_mean_absolute_error: 3387.2537 - val_root_mean_squared_error: 4258.1060
# Epoch 4/100
# 390/390 [==============================] - 1s 3ms/step - loss: 13726056.0000 - mean_absolute_error: 2919.1438 - root_mean_squared_error: 3704.8691 - val_loss: 9940598.0000 - val_mean_absolute_error: 2497.9407 - val_root_mean_squared_error: 3152.8713
# Epoch 5/100
# 390/390 [==============================] - 1s 3ms/step - loss: 6984372.5000 - mean_absolute_error: 2066.3315 - root_mean_squared_error: 2642.7964 - val_loss: 4718871.0000 - val_mean_absolute_error: 1694.2628 - val_root_mean_squared_error: 2172.2961
# Epoch 6/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3198240.0000 - mean_absolute_error: 1376.8065 - root_mean_squared_error: 1788.3624 - val_loss: 2298926.0000 - val_mean_absolute_error: 1148.9252 - val_root_mean_squared_error: 1516.2209
# Epoch 7/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1725323.7500 - mean_absolute_error: 1004.0312 - root_mean_squared_error: 1313.5157 - val_loss: 1549623.6250 - val_mean_absolute_error: 938.7074 - val_root_mean_squared_error: 1244.8387
# Epoch 8/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1349096.8750 - mean_absolute_error: 892.1954 - root_mean_squared_error: 1161.5063 - val_loss: 1393088.3750 - val_mean_absolute_error: 892.4009 - val_root_mean_squared_error: 1180.2916
# Epoch 9/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1275711.8750 - mean_absolute_error: 873.6410 - root_mean_squared_error: 1129.4741 - val_loss: 1349361.6250 - val_mean_absolute_error: 880.3343 - val_root_mean_squared_error: 1161.6202
# Epoch 10/100
# 390/390 [==============================] - 2s 4ms/step - loss: 1249956.6250 - mean_absolute_error: 868.9653 - root_mean_squared_error: 1118.0146 - val_loss: 1321893.0000 - val_mean_absolute_error: 879.2557 - val_root_mean_squared_error: 1149.7361
# Epoch 11/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1235597.3750 - mean_absolute_error: 866.9150 - root_mean_squared_error: 1111.5742 - val_loss: 1322304.8750 - val_mean_absolute_error: 883.8472 - val_root_mean_squared_error: 1149.9152
# Epoch 12/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1218208.1250 - mean_absolute_error: 862.3228 - root_mean_squared_error: 1103.7246 - val_loss: 1287805.1250 - val_mean_absolute_error: 873.0479 - val_root_mean_squared_error: 1134.8151
# Epoch 13/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1203404.0000 - mean_absolute_error: 857.9364 - root_mean_squared_error: 1096.9977 - val_loss: 1275313.2500 - val_mean_absolute_error: 865.0067 - val_root_mean_squared_error: 1129.2977
# Epoch 14/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1187028.3750 - mean_absolute_error: 851.4346 - root_mean_squared_error: 1089.5083 - val_loss: 1250388.1250 - val_mean_absolute_error: 854.6915 - val_root_mean_squared_error: 1118.2075
# Epoch 15/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1164286.0000 - mean_absolute_error: 843.9122 - root_mean_squared_error: 1079.0209 - val_loss: 1256247.5000 - val_mean_absolute_error: 858.9202 - val_root_mean_squared_error: 1120.8245
# Epoch 16/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1149719.0000 - mean_absolute_error: 836.6351 - root_mean_squared_error: 1072.2495 - val_loss: 1222369.6250 - val_mean_absolute_error: 847.0279 - val_root_mean_squared_error: 1105.6083
# Epoch 17/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1128298.5000 - mean_absolute_error: 828.6519 - root_mean_squared_error: 1062.2140 - val_loss: 1193747.6250 - val_mean_absolute_error: 837.9478 - val_root_mean_squared_error: 1092.5875
# Epoch 18/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1108809.3750 - mean_absolute_error: 823.0746 - root_mean_squared_error: 1053.0001 - val_loss: 1204309.3750 - val_mean_absolute_error: 840.5143 - val_root_mean_squared_error: 1097.4103
# Epoch 19/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1088434.5000 - mean_absolute_error: 815.2048 - root_mean_squared_error: 1043.2806 - val_loss: 1163176.3750 - val_mean_absolute_error: 822.2676 - val_root_mean_squared_error: 1078.5066
# Epoch 20/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1075339.7500 - mean_absolute_error: 810.0306 - root_mean_squared_error: 1036.9858 - val_loss: 1156129.8750 - val_mean_absolute_error: 821.9003 - val_root_mean_squared_error: 1075.2347
# Epoch 21/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1060907.0000 - mean_absolute_error: 802.5167 - root_mean_squared_error: 1030.0034 - val_loss: 1131769.8750 - val_mean_absolute_error: 810.2602 - val_root_mean_squared_error: 1063.8467
# Epoch 22/100
# 390/390 [==============================] - 2s 4ms/step - loss: 1047499.0000 - mean_absolute_error: 798.4559 - root_mean_squared_error: 1023.4740 - val_loss: 1145263.6250 - val_mean_absolute_error: 817.0094 - val_root_mean_squared_error: 1070.1699
# Epoch 23/100
# 390/390 [==============================] - 2s 4ms/step - loss: 1028838.8750 - mean_absolute_error: 792.0258 - root_mean_squared_error: 1014.3170 - val_loss: 1111103.8750 - val_mean_absolute_error: 800.1880 - val_root_mean_squared_error: 1054.0891
# Epoch 24/100
# 390/390 [==============================] - 1s 2ms/step - loss: 1020755.2500 - mean_absolute_error: 787.4819 - root_mean_squared_error: 1010.3243 - val_loss: 1108033.6250 - val_mean_absolute_error: 800.2950 - val_root_mean_squared_error: 1052.6317
# Epoch 25/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1009806.7500 - mean_absolute_error: 781.9220 - root_mean_squared_error: 1004.8914 - val_loss: 1092965.5000 - val_mean_absolute_error: 794.2255 - val_root_mean_squared_error: 1045.4500
# Epoch 26/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1002912.5000 - mean_absolute_error: 779.8062 - root_mean_squared_error: 1001.4552 - val_loss: 1080913.3750 - val_mean_absolute_error: 787.0873 - val_root_mean_squared_error: 1039.6698
# Epoch 27/100
# 390/390 [==============================] - 1s 2ms/step - loss: 992258.6875 - mean_absolute_error: 775.1190 - root_mean_squared_error: 996.1218 - val_loss: 1072144.8750 - val_mean_absolute_error: 783.4632 - val_root_mean_squared_error: 1035.4443
# Epoch 28/100
# 390/390 [==============================] - 1s 2ms/step - loss: 986146.6875 - mean_absolute_error: 772.6298 - root_mean_squared_error: 993.0492 - val_loss: 1063946.1250 - val_mean_absolute_error: 779.1602 - val_root_mean_squared_error: 1031.4777
# Epoch 29/100
# 390/390 [==============================] - 1s 3ms/step - loss: 977913.8125 - mean_absolute_error: 766.2830 - root_mean_squared_error: 988.8953 - val_loss: 1066094.8750 - val_mean_absolute_error: 779.9894 - val_root_mean_squared_error: 1032.5187
# Epoch 30/100
# 390/390 [==============================] - 1s 3ms/step - loss: 979307.6875 - mean_absolute_error: 767.8528 - root_mean_squared_error: 989.5997 - val_loss: 1056135.1250 - val_mean_absolute_error: 775.8599 - val_root_mean_squared_error: 1027.6843
# Epoch 31/100
# 390/390 [==============================] - 1s 3ms/step - loss: 968501.3125 - mean_absolute_error: 763.8030 - root_mean_squared_error: 984.1246 - val_loss: 1076965.0000 - val_mean_absolute_error: 782.1901 - val_root_mean_squared_error: 1037.7693
# Epoch 32/100
# 390/390 [==============================] - 1s 3ms/step - loss: 964406.8750 - mean_absolute_error: 760.5340 - root_mean_squared_error: 982.0422 - val_loss: 1045590.2500 - val_mean_absolute_error: 771.6866 - val_root_mean_squared_error: 1022.5411
# Epoch 33/100
# 390/390 [==============================] - 1s 3ms/step - loss: 960862.8750 - mean_absolute_error: 760.7472 - root_mean_squared_error: 980.2361 - val_loss: 1065829.2500 - val_mean_absolute_error: 775.5801 - val_root_mean_squared_error: 1032.3900
# Epoch 34/100
# 390/390 [==============================] - 2s 4ms/step - loss: 957653.9375 - mean_absolute_error: 758.0441 - root_mean_squared_error: 978.5980 - val_loss: 1040818.5000 - val_mean_absolute_error: 768.8746 - val_root_mean_squared_error: 1020.2051
# Epoch 35/100
# 390/390 [==============================] - 1s 4ms/step - loss: 951523.8125 - mean_absolute_error: 755.0028 - root_mean_squared_error: 975.4608 - val_loss: 1042875.6250 - val_mean_absolute_error: 773.2754 - val_root_mean_squared_error: 1021.2128
# Epoch 36/100
# 390/390 [==============================] - 1s 2ms/step - loss: 950935.7500 - mean_absolute_error: 755.4110 - root_mean_squared_error: 975.1594 - val_loss: 1047592.3125 - val_mean_absolute_error: 769.9680 - val_root_mean_squared_error: 1023.5196
# Epoch 37/100
# 390/390 [==============================] - 1s 3ms/step - loss: 946831.8125 - mean_absolute_error: 752.8028 - root_mean_squared_error: 973.0529 - val_loss: 1037720.7500 - val_mean_absolute_error: 765.4766 - val_root_mean_squared_error: 1018.6858
# Epoch 38/100
# 390/390 [==============================] - 1s 3ms/step - loss: 943023.3125 - mean_absolute_error: 751.2194 - root_mean_squared_error: 971.0939 - val_loss: 1021542.3125 - val_mean_absolute_error: 761.3263 - val_root_mean_squared_error: 1010.7137
# Epoch 39/100
# 390/390 [==============================] - 1s 2ms/step - loss: 939490.1250 - mean_absolute_error: 748.9814 - root_mean_squared_error: 969.2730 - val_loss: 1019129.8750 - val_mean_absolute_error: 760.8934 - val_root_mean_squared_error: 1009.5197
# Epoch 40/100
# 390/390 [==============================] - 1s 3ms/step - loss: 935536.5000 - mean_absolute_error: 747.9742 - root_mean_squared_error: 967.2314 - val_loss: 1018980.8750 - val_mean_absolute_error: 756.7518 - val_root_mean_squared_error: 1009.4458
# Epoch 41/100
# 390/390 [==============================] - 1s 3ms/step - loss: 935485.0000 - mean_absolute_error: 746.5577 - root_mean_squared_error: 967.2047 - val_loss: 1021383.2500 - val_mean_absolute_error: 763.1831 - val_root_mean_squared_error: 1010.6351
# Epoch 42/100
# 390/390 [==============================] - 1s 2ms/step - loss: 930418.8750 - mean_absolute_error: 744.6804 - root_mean_squared_error: 964.5822 - val_loss: 1015535.7500 - val_mean_absolute_error: 761.1696 - val_root_mean_squared_error: 1007.7379
# Epoch 43/100
# 390/390 [==============================] - 1s 3ms/step - loss: 925464.9375 - mean_absolute_error: 743.6118 - root_mean_squared_error: 962.0109 - val_loss: 1034069.4375 - val_mean_absolute_error: 768.9094 - val_root_mean_squared_error: 1016.8920
# Epoch 44/100
# 390/390 [==============================] - 1s 3ms/step - loss: 921198.0625 - mean_absolute_error: 740.2401 - root_mean_squared_error: 959.7906 - val_loss: 1001780.6875 - val_mean_absolute_error: 753.9795 - val_root_mean_squared_error: 1000.8900
# Epoch 45/100
# 390/390 [==============================] - 1s 4ms/step - loss: 918094.7500 - mean_absolute_error: 739.1062 - root_mean_squared_error: 958.1726 - val_loss: 1009550.0625 - val_mean_absolute_error: 755.4427 - val_root_mean_squared_error: 1004.7637
# Epoch 46/100
# 390/390 [==============================] - 2s 4ms/step - loss: 919960.8750 - mean_absolute_error: 740.7585 - root_mean_squared_error: 959.1459 - val_loss: 1007426.6875 - val_mean_absolute_error: 754.0001 - val_root_mean_squared_error: 1003.7065
# Epoch 47/100
# 390/390 [==============================] - 1s 3ms/step - loss: 911919.3750 - mean_absolute_error: 735.7818 - root_mean_squared_error: 954.9447 - val_loss: 996264.3125 - val_mean_absolute_error: 750.3253 - val_root_mean_squared_error: 998.1304
# Epoch 48/100
# 390/390 [==============================] - 1s 3ms/step - loss: 907625.5625 - mean_absolute_error: 735.3934 - root_mean_squared_error: 952.6938 - val_loss: 997628.2500 - val_mean_absolute_error: 748.7617 - val_root_mean_squared_error: 998.8134
# Epoch 49/100
# 390/390 [==============================] - 1s 3ms/step - loss: 908513.2500 - mean_absolute_error: 734.3950 - root_mean_squared_error: 953.1596 - val_loss: 989243.8750 - val_mean_absolute_error: 751.8530 - val_root_mean_squared_error: 994.6074
# Epoch 50/100
# 390/390 [==============================] - 1s 2ms/step - loss: 904019.8750 - mean_absolute_error: 734.1855 - root_mean_squared_error: 950.7996 - val_loss: 992545.1875 - val_mean_absolute_error: 749.2067 - val_root_mean_squared_error: 996.2656
# Epoch 51/100
# 390/390 [==============================] - 1s 2ms/step - loss: 906670.0000 - mean_absolute_error: 733.5950 - root_mean_squared_error: 952.1922 - val_loss: 986672.6250 - val_mean_absolute_error: 746.1865 - val_root_mean_squared_error: 993.3140
# Epoch 52/100
# 390/390 [==============================] - 1s 3ms/step - loss: 902199.6250 - mean_absolute_error: 732.9739 - root_mean_squared_error: 949.8419 - val_loss: 1000164.6875 - val_mean_absolute_error: 754.8510 - val_root_mean_squared_error: 1000.0823
# Epoch 53/100
# 390/390 [==============================] - 1s 2ms/step - loss: 896575.8125 - mean_absolute_error: 729.2376 - root_mean_squared_error: 946.8769 - val_loss: 979381.7500 - val_mean_absolute_error: 742.4540 - val_root_mean_squared_error: 989.6372
# Epoch 54/100
# 390/390 [==============================] - 1s 3ms/step - loss: 893851.7500 - mean_absolute_error: 728.9232 - root_mean_squared_error: 945.4373 - val_loss: 984927.4375 - val_mean_absolute_error: 749.1629 - val_root_mean_squared_error: 992.4351
# Epoch 55/100
# 390/390 [==============================] - 1s 3ms/step - loss: 893153.4375 - mean_absolute_error: 728.4672 - root_mean_squared_error: 945.0679 - val_loss: 1001530.0000 - val_mean_absolute_error: 755.1483 - val_root_mean_squared_error: 1000.7647
# Epoch 56/100
# 390/390 [==============================] - 1s 3ms/step - loss: 887335.1250 - mean_absolute_error: 725.7061 - root_mean_squared_error: 941.9847 - val_loss: 987310.5000 - val_mean_absolute_error: 752.7195 - val_root_mean_squared_error: 993.6350
# Epoch 57/100
# 390/390 [==============================] - 1s 4ms/step - loss: 893402.5000 - mean_absolute_error: 727.7966 - root_mean_squared_error: 945.1997 - val_loss: 980138.7500 - val_mean_absolute_error: 742.2302 - val_root_mean_squared_error: 990.0196
# Epoch 58/100
# 390/390 [==============================] - 2s 4ms/step - loss: 887276.4375 - mean_absolute_error: 724.9872 - root_mean_squared_error: 941.9536 - val_loss: 980966.1875 - val_mean_absolute_error: 746.4078 - val_root_mean_squared_error: 990.4374
# Epoch 59/100
# 390/390 [==============================] - 1s 4ms/step - loss: 888524.9375 - mean_absolute_error: 726.7856 - root_mean_squared_error: 942.6160 - val_loss: 992014.6250 - val_mean_absolute_error: 750.5922 - val_root_mean_squared_error: 995.9993
# Epoch 60/100
# 390/390 [==============================] - 1s 3ms/step - loss: 888502.5000 - mean_absolute_error: 726.9551 - root_mean_squared_error: 942.6041 - val_loss: 1011266.3125 - val_mean_absolute_error: 747.9693 - val_root_mean_squared_error: 1005.6174
# Epoch 61/100
# 390/390 [==============================] - 1s 3ms/step - loss: 879786.3125 - mean_absolute_error: 720.7986 - root_mean_squared_error: 937.9692 - val_loss: 975216.6250 - val_mean_absolute_error: 739.7170 - val_root_mean_squared_error: 987.5306
# Epoch 62/100
# 390/390 [==============================] - 1s 2ms/step - loss: 880669.8750 - mean_absolute_error: 722.6927 - root_mean_squared_error: 938.4401 - val_loss: 966536.4375 - val_mean_absolute_error: 738.8057 - val_root_mean_squared_error: 983.1259
# Epoch 63/100
# 390/390 [==============================] - 1s 2ms/step - loss: 879332.1875 - mean_absolute_error: 721.7095 - root_mean_squared_error: 937.7271 - val_loss: 1014605.3125 - val_mean_absolute_error: 763.4335 - val_root_mean_squared_error: 1007.2762
# Epoch 64/100
# 390/390 [==============================] - 1s 3ms/step - loss: 881699.8125 - mean_absolute_error: 722.9363 - root_mean_squared_error: 938.9887 - val_loss: 965771.9375 - val_mean_absolute_error: 737.3389 - val_root_mean_squared_error: 982.7369
# Epoch 65/100
# 390/390 [==============================] - 1s 2ms/step - loss: 872668.8125 - mean_absolute_error: 717.3486 - root_mean_squared_error: 934.1674 - val_loss: 990731.0000 - val_mean_absolute_error: 746.5363 - val_root_mean_squared_error: 995.3547
# Epoch 66/100
# 390/390 [==============================] - 1s 2ms/step - loss: 874063.0000 - mean_absolute_error: 719.1938 - root_mean_squared_error: 934.9134 - val_loss: 962355.0000 - val_mean_absolute_error: 735.2549 - val_root_mean_squared_error: 980.9969
# Epoch 67/100
# 390/390 [==============================] - 1s 3ms/step - loss: 871224.0625 - mean_absolute_error: 717.7023 - root_mean_squared_error: 933.3939 - val_loss: 965149.8750 - val_mean_absolute_error: 734.2812 - val_root_mean_squared_error: 982.4204
# Epoch 68/100
# 390/390 [==============================] - 1s 3ms/step - loss: 873048.2500 - mean_absolute_error: 717.8292 - root_mean_squared_error: 934.3705 - val_loss: 956199.1250 - val_mean_absolute_error: 732.1105 - val_root_mean_squared_error: 977.8544
# Epoch 69/100
# 390/390 [==============================] - 2s 4ms/step - loss: 866828.6875 - mean_absolute_error: 714.7460 - root_mean_squared_error: 931.0364 - val_loss: 969466.1875 - val_mean_absolute_error: 734.4327 - val_root_mean_squared_error: 984.6147
# Epoch 70/100
# 390/390 [==============================] - 2s 4ms/step - loss: 872027.6250 - mean_absolute_error: 717.5100 - root_mean_squared_error: 933.8242 - val_loss: 969586.9375 - val_mean_absolute_error: 735.5615 - val_root_mean_squared_error: 984.6761
# Epoch 71/100
# 390/390 [==============================] - 1s 3ms/step - loss: 869151.7500 - mean_absolute_error: 717.4303 - root_mean_squared_error: 932.2831 - val_loss: 957358.9375 - val_mean_absolute_error: 733.3792 - val_root_mean_squared_error: 978.4472
# Epoch 72/100
# 390/390 [==============================] - 1s 3ms/step - loss: 863098.3125 - mean_absolute_error: 714.0797 - root_mean_squared_error: 929.0308 - val_loss: 957242.0000 - val_mean_absolute_error: 733.7531 - val_root_mean_squared_error: 978.3875
# Epoch 73/100
# 390/390 [==============================] - 1s 3ms/step - loss: 863630.5625 - mean_absolute_error: 714.5873 - root_mean_squared_error: 929.3173 - val_loss: 956645.5625 - val_mean_absolute_error: 731.2882 - val_root_mean_squared_error: 978.0826
# Epoch 74/100
# 390/390 [==============================] - 1s 3ms/step - loss: 864615.0625 - mean_absolute_error: 713.4986 - root_mean_squared_error: 929.8468 - val_loss: 954281.9375 - val_mean_absolute_error: 732.3201 - val_root_mean_squared_error: 976.8735
# Epoch 75/100
# 390/390 [==============================] - 1s 2ms/step - loss: 868047.9375 - mean_absolute_error: 715.8537 - root_mean_squared_error: 931.6909 - val_loss: 966948.3750 - val_mean_absolute_error: 736.4878 - val_root_mean_squared_error: 983.3353
# Epoch 76/100
# 390/390 [==============================] - 1s 3ms/step - loss: 858938.5625 - mean_absolute_error: 711.3545 - root_mean_squared_error: 926.7894 - val_loss: 956459.0000 - val_mean_absolute_error: 733.6860 - val_root_mean_squared_error: 977.9872
# Epoch 77/100
# 390/390 [==============================] - 1s 3ms/step - loss: 861388.0000 - mean_absolute_error: 711.9732 - root_mean_squared_error: 928.1099 - val_loss: 945985.7500 - val_mean_absolute_error: 728.2825 - val_root_mean_squared_error: 972.6180
# Epoch 78/100
# 390/390 [==============================] - 1s 3ms/step - loss: 863051.6250 - mean_absolute_error: 714.2860 - root_mean_squared_error: 929.0057 - val_loss: 947278.0625 - val_mean_absolute_error: 727.8284 - val_root_mean_squared_error: 973.2821
# Epoch 79/100
# 390/390 [==============================] - 1s 3ms/step - loss: 860592.1250 - mean_absolute_error: 711.8940 - root_mean_squared_error: 927.6810 - val_loss: 946632.6250 - val_mean_absolute_error: 729.4996 - val_root_mean_squared_error: 972.9505
# Epoch 80/100
# 390/390 [==============================] - 1s 3ms/step - loss: 860528.6250 - mean_absolute_error: 711.3309 - root_mean_squared_error: 927.6469 - val_loss: 951693.6875 - val_mean_absolute_error: 736.8820 - val_root_mean_squared_error: 975.5479
# Epoch 81/100
# 390/390 [==============================] - 1s 4ms/step - loss: 857681.7500 - mean_absolute_error: 711.8129 - root_mean_squared_error: 926.1111 - val_loss: 985056.5625 - val_mean_absolute_error: 738.0480 - val_root_mean_squared_error: 992.5002
# Epoch 82/100
# 390/390 [==============================] - 1s 4ms/step - loss: 857157.6875 - mean_absolute_error: 709.7996 - root_mean_squared_error: 925.8281 - val_loss: 960685.8750 - val_mean_absolute_error: 734.8441 - val_root_mean_squared_error: 980.1459
# Epoch 83/100
# 390/390 [==============================] - 1s 2ms/step - loss: 858117.2500 - mean_absolute_error: 711.1304 - root_mean_squared_error: 926.3462 - val_loss: 957389.1250 - val_mean_absolute_error: 730.6404 - val_root_mean_squared_error: 978.4626
# Epoch 84/100
# 390/390 [==============================] - 1s 3ms/step - loss: 852680.6250 - mean_absolute_error: 707.6566 - root_mean_squared_error: 923.4071 - val_loss: 943743.3750 - val_mean_absolute_error: 728.5544 - val_root_mean_squared_error: 971.4645
# Epoch 85/100
# 390/390 [==============================] - 1s 3ms/step - loss: 852008.8125 - mean_absolute_error: 708.4886 - root_mean_squared_error: 923.0432 - val_loss: 979728.4375 - val_mean_absolute_error: 739.4247 - val_root_mean_squared_error: 989.8123
# Epoch 86/100
# 390/390 [==============================] - 1s 2ms/step - loss: 852197.9375 - mean_absolute_error: 707.0885 - root_mean_squared_error: 923.1457 - val_loss: 947823.1250 - val_mean_absolute_error: 732.3566 - val_root_mean_squared_error: 973.5621
# Epoch 87/100
# 390/390 [==============================] - 1s 2ms/step - loss: 849256.2500 - mean_absolute_error: 705.4452 - root_mean_squared_error: 921.5510 - val_loss: 952361.0000 - val_mean_absolute_error: 734.8827 - val_root_mean_squared_error: 975.8898
# Epoch 88/100
# 390/390 [==============================] - 1s 2ms/step - loss: 849129.8750 - mean_absolute_error: 706.9205 - root_mean_squared_error: 921.4824 - val_loss: 948447.3125 - val_mean_absolute_error: 730.7848 - val_root_mean_squared_error: 973.8826
# Epoch 89/100
# 390/390 [==============================] - 1s 3ms/step - loss: 850773.0625 - mean_absolute_error: 708.3506 - root_mean_squared_error: 922.3736 - val_loss: 937502.3125 - val_mean_absolute_error: 728.6745 - val_root_mean_squared_error: 968.2470
# Epoch 90/100
# 390/390 [==============================] - 1s 3ms/step - loss: 847197.0000 - mean_absolute_error: 706.3388 - root_mean_squared_error: 920.4330 - val_loss: 942004.5625 - val_mean_absolute_error: 729.8536 - val_root_mean_squared_error: 970.5692
# Epoch 91/100
# 390/390 [==============================] - 1s 2ms/step - loss: 844505.3125 - mean_absolute_error: 707.8887 - root_mean_squared_error: 918.9697 - val_loss: 943944.8125 - val_mean_absolute_error: 727.0688 - val_root_mean_squared_error: 971.5682
# Epoch 92/100
# 390/390 [==============================] - 1s 3ms/step - loss: 851241.1250 - mean_absolute_error: 707.8411 - root_mean_squared_error: 922.6273 - val_loss: 936356.6875 - val_mean_absolute_error: 724.6860 - val_root_mean_squared_error: 967.6553
# Epoch 93/100
# 390/390 [==============================] - 1s 4ms/step - loss: 846508.7500 - mean_absolute_error: 704.8755 - root_mean_squared_error: 920.0591 - val_loss: 947614.8750 - val_mean_absolute_error: 730.8022 - val_root_mean_squared_error: 973.4551
# Epoch 94/100
# 390/390 [==============================] - 2s 4ms/step - loss: 845882.5625 - mean_absolute_error: 705.2829 - root_mean_squared_error: 919.7188 - val_loss: 939288.7500 - val_mean_absolute_error: 729.9243 - val_root_mean_squared_error: 969.1691
# Epoch 95/100
# 390/390 [==============================] - 1s 3ms/step - loss: 843519.1250 - mean_absolute_error: 705.9512 - root_mean_squared_error: 918.4330 - val_loss: 954521.9375 - val_mean_absolute_error: 729.6345 - val_root_mean_squared_error: 976.9964
# Epoch 96/100
# 390/390 [==============================] - 1s 3ms/step - loss: 843061.5625 - mean_absolute_error: 704.1163 - root_mean_squared_error: 918.1838 - val_loss: 954708.5000 - val_mean_absolute_error: 734.9415 - val_root_mean_squared_error: 977.0919
# Epoch 97/100
# 390/390 [==============================] - 1s 2ms/step - loss: 842910.3125 - mean_absolute_error: 704.2662 - root_mean_squared_error: 918.1015 - val_loss: 937446.8750 - val_mean_absolute_error: 726.0728 - val_root_mean_squared_error: 968.2184
# Epoch 98/100
# 390/390 [==============================] - 1s 3ms/step - loss: 839496.8750 - mean_absolute_error: 702.3220 - root_mean_squared_error: 916.2406 - val_loss: 940572.2500 - val_mean_absolute_error: 724.8999 - val_root_mean_squared_error: 969.8311
# Epoch 99/100
# 390/390 [==============================] - 1s 2ms/step - loss: 839670.6875 - mean_absolute_error: 703.8298 - root_mean_squared_error: 916.3354 - val_loss: 939174.7500 - val_mean_absolute_error: 728.3291 - val_root_mean_squared_error: 969.1103
# Epoch 100/100
# 390/390 [==============================] - 1s 3ms/step - loss: 839649.8750 - mean_absolute_error: 703.2770 - root_mean_squared_error: 916.3241 - val_loss: 939099.2500 - val_mean_absolute_error: 727.4233 - val_root_mean_squared_error: 969.0714

# %%
# Get predictions
y_pred_train_1 = model_1.predict(X_train_tf)
y_pred_test_1 = model_1.predict(X_test_tf)
# Out:
# 390/390 [==============================] - 1s 1ms/step
# 130/130 [==============================] - 0s 2ms/step

# %%
# Model Sequential
model_2 = Sequential()

# Hidden layers
model_2.add(Dense(37, input_dim = X_train_tf.shape[1], activation='relu'))
model_2.add(Dropout(.2))
model_2.add(Dense(25, activation='relu'))
model_2.add(Dropout(.2))
model_2.add(Dense(10, activation='relu'))
model_2.add(Dropout(.2))

# Output layer
model_2.add(Dense(1, activation='linear'))

# Compile the model
model_2.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.RootMeanSquaredError()])

# Fit the model
history = model_2.fit(X_train_tf, y_train,
                    validation_data = (X_test_tf, y_test),
                    epochs = 100,
                    batch_size = 32)
# Out:
# Epoch 1/100
# 390/390 [==============================] - 3s 3ms/step - loss: 501215680.0000 - mean_absolute_error: 19183.8633 - root_mean_squared_error: 22387.8477 - val_loss: 116091912.0000 - val_mean_absolute_error: 8500.7383 - val_root_mean_squared_error: 10774.5957
# Epoch 2/100
# 390/390 [==============================] - 1s 3ms/step - loss: 69583032.0000 - mean_absolute_error: 6408.8516 - root_mean_squared_error: 8341.6445 - val_loss: 28437882.0000 - val_mean_absolute_error: 4175.7471 - val_root_mean_squared_error: 5332.7183
# Epoch 3/100
# 390/390 [==============================] - 1s 3ms/step - loss: 51379184.0000 - mean_absolute_error: 5457.4902 - root_mean_squared_error: 7167.9272 - val_loss: 16115112.0000 - val_mean_absolute_error: 3153.4368 - val_root_mean_squared_error: 4014.3633
# Epoch 4/100
# 390/390 [==============================] - 1s 3ms/step - loss: 43093136.0000 - mean_absolute_error: 4927.2720 - root_mean_squared_error: 6564.5361 - val_loss: 9381257.0000 - val_mean_absolute_error: 2380.8721 - val_root_mean_squared_error: 3062.8838
# Epoch 5/100
# 390/390 [==============================] - 1s 4ms/step - loss: 38530232.0000 - mean_absolute_error: 4564.5874 - root_mean_squared_error: 6207.2725 - val_loss: 5095576.0000 - val_mean_absolute_error: 1709.8269 - val_root_mean_squared_error: 2257.3381
# Epoch 6/100
# 390/390 [==============================] - 2s 4ms/step - loss: 35485644.0000 - mean_absolute_error: 4358.5977 - root_mean_squared_error: 5956.9829 - val_loss: 4202770.5000 - val_mean_absolute_error: 1548.6495 - val_root_mean_squared_error: 2050.0659
# Epoch 7/100
# 390/390 [==============================] - 1s 4ms/step - loss: 34076968.0000 - mean_absolute_error: 4221.5630 - root_mean_squared_error: 5837.5483 - val_loss: 3482295.7500 - val_mean_absolute_error: 1393.2367 - val_root_mean_squared_error: 1866.0911
# Epoch 8/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33780332.0000 - mean_absolute_error: 4190.4238 - root_mean_squared_error: 5812.0850 - val_loss: 2621779.7500 - val_mean_absolute_error: 1208.2979 - val_root_mean_squared_error: 1619.1910
# Epoch 9/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33808248.0000 - mean_absolute_error: 4210.6079 - root_mean_squared_error: 5814.4858 - val_loss: 3585386.7500 - val_mean_absolute_error: 1451.2350 - val_root_mean_squared_error: 1893.5117
# Epoch 10/100
# 390/390 [==============================] - 1s 3ms/step - loss: 34258904.0000 - mean_absolute_error: 4185.8291 - root_mean_squared_error: 5853.1108 - val_loss: 2673437.2500 - val_mean_absolute_error: 1224.1846 - val_root_mean_squared_error: 1635.0649
# Epoch 11/100
# 390/390 [==============================] - 1s 3ms/step - loss: 34004220.0000 - mean_absolute_error: 4212.3442 - root_mean_squared_error: 5831.3140 - val_loss: 3696040.5000 - val_mean_absolute_error: 1480.1501 - val_root_mean_squared_error: 1922.5089
# Epoch 12/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33008738.0000 - mean_absolute_error: 4136.3682 - root_mean_squared_error: 5745.3232 - val_loss: 2524409.7500 - val_mean_absolute_error: 1188.3239 - val_root_mean_squared_error: 1588.8391
# Epoch 13/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33917560.0000 - mean_absolute_error: 4207.3257 - root_mean_squared_error: 5823.8784 - val_loss: 2575641.5000 - val_mean_absolute_error: 1201.8822 - val_root_mean_squared_error: 1604.8805
# Epoch 14/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33832952.0000 - mean_absolute_error: 4181.3159 - root_mean_squared_error: 5816.6099 - val_loss: 2758627.2500 - val_mean_absolute_error: 1243.5837 - val_root_mean_squared_error: 1660.9116
# Epoch 15/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33319194.0000 - mean_absolute_error: 4177.8867 - root_mean_squared_error: 5772.2778 - val_loss: 2274804.2500 - val_mean_absolute_error: 1110.7213 - val_root_mean_squared_error: 1508.2454
# Epoch 16/100
# 390/390 [==============================] - 1s 4ms/step - loss: 33541304.0000 - mean_absolute_error: 4197.2515 - root_mean_squared_error: 5791.4854 - val_loss: 3164749.2500 - val_mean_absolute_error: 1337.7793 - val_root_mean_squared_error: 1778.9742
# Epoch 17/100
# 390/390 [==============================] - 2s 4ms/step - loss: 33277638.0000 - mean_absolute_error: 4158.4019 - root_mean_squared_error: 5768.6772 - val_loss: 2648858.0000 - val_mean_absolute_error: 1219.1685 - val_root_mean_squared_error: 1627.5312
# Epoch 18/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32642912.0000 - mean_absolute_error: 4128.7500 - root_mean_squared_error: 5713.3975 - val_loss: 2702152.0000 - val_mean_absolute_error: 1254.9384 - val_root_mean_squared_error: 1643.8224
# Epoch 19/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33138408.0000 - mean_absolute_error: 4175.7056 - root_mean_squared_error: 5756.5967 - val_loss: 2748174.2500 - val_mean_absolute_error: 1263.0049 - val_root_mean_squared_error: 1657.7618
# Epoch 20/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33565724.0000 - mean_absolute_error: 4149.1387 - root_mean_squared_error: 5793.5933 - val_loss: 2749479.5000 - val_mean_absolute_error: 1259.1332 - val_root_mean_squared_error: 1658.1554
# Epoch 21/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33259518.0000 - mean_absolute_error: 4145.0693 - root_mean_squared_error: 5767.1064 - val_loss: 2868867.2500 - val_mean_absolute_error: 1265.7319 - val_root_mean_squared_error: 1693.7731
# Epoch 22/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32409260.0000 - mean_absolute_error: 4121.0718 - root_mean_squared_error: 5692.9131 - val_loss: 2941146.2500 - val_mean_absolute_error: 1299.6968 - val_root_mean_squared_error: 1714.9771
# Epoch 23/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33004560.0000 - mean_absolute_error: 4124.7715 - root_mean_squared_error: 5744.9595 - val_loss: 2533963.0000 - val_mean_absolute_error: 1203.5884 - val_root_mean_squared_error: 1591.8427
# Epoch 24/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32400564.0000 - mean_absolute_error: 4116.8188 - root_mean_squared_error: 5692.1494 - val_loss: 2950022.2500 - val_mean_absolute_error: 1301.3594 - val_root_mean_squared_error: 1717.5629
# Epoch 25/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33090674.0000 - mean_absolute_error: 4145.0171 - root_mean_squared_error: 5752.4492 - val_loss: 3151931.5000 - val_mean_absolute_error: 1366.6752 - val_root_mean_squared_error: 1775.3680
# Epoch 26/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33462560.0000 - mean_absolute_error: 4163.9927 - root_mean_squared_error: 5784.6831 - val_loss: 2918543.0000 - val_mean_absolute_error: 1293.6552 - val_root_mean_squared_error: 1708.3744
# Epoch 27/100
# 390/390 [==============================] - 1s 4ms/step - loss: 33608416.0000 - mean_absolute_error: 4164.4131 - root_mean_squared_error: 5797.2764 - val_loss: 3181708.2500 - val_mean_absolute_error: 1382.2892 - val_root_mean_squared_error: 1783.7344
# Epoch 28/100
# 390/390 [==============================] - 2s 4ms/step - loss: 32777108.0000 - mean_absolute_error: 4107.9463 - root_mean_squared_error: 5725.1294 - val_loss: 2687662.7500 - val_mean_absolute_error: 1240.4141 - val_root_mean_squared_error: 1639.4093
# Epoch 29/100
# 390/390 [==============================] - 1s 4ms/step - loss: 33811336.0000 - mean_absolute_error: 4176.4985 - root_mean_squared_error: 5814.7515 - val_loss: 2619252.7500 - val_mean_absolute_error: 1208.5024 - val_root_mean_squared_error: 1618.4105
# Epoch 30/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33282992.0000 - mean_absolute_error: 4143.5596 - root_mean_squared_error: 5769.1411 - val_loss: 2836567.0000 - val_mean_absolute_error: 1268.8063 - val_root_mean_squared_error: 1684.2111
# Epoch 31/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33426092.0000 - mean_absolute_error: 4124.3042 - root_mean_squared_error: 5781.5303 - val_loss: 2190661.0000 - val_mean_absolute_error: 1088.2506 - val_root_mean_squared_error: 1480.0881
# Epoch 32/100
# 390/390 [==============================] - 1s 3ms/step - loss: 34471984.0000 - mean_absolute_error: 4191.4097 - root_mean_squared_error: 5871.2847 - val_loss: 2393836.2500 - val_mean_absolute_error: 1166.8054 - val_root_mean_squared_error: 1547.2028
# Epoch 33/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32588634.0000 - mean_absolute_error: 4110.0703 - root_mean_squared_error: 5708.6455 - val_loss: 2847504.5000 - val_mean_absolute_error: 1265.2188 - val_root_mean_squared_error: 1687.4551
# Epoch 34/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32470728.0000 - mean_absolute_error: 4099.8989 - root_mean_squared_error: 5698.3091 - val_loss: 2935402.2500 - val_mean_absolute_error: 1311.0667 - val_root_mean_squared_error: 1713.3015
# Epoch 35/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33126280.0000 - mean_absolute_error: 4113.1987 - root_mean_squared_error: 5755.5435 - val_loss: 3104847.5000 - val_mean_absolute_error: 1317.3678 - val_root_mean_squared_error: 1762.0577
# Epoch 36/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32343310.0000 - mean_absolute_error: 4096.6636 - root_mean_squared_error: 5687.1177 - val_loss: 3555172.0000 - val_mean_absolute_error: 1444.0131 - val_root_mean_squared_error: 1885.5164
# Epoch 37/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32618958.0000 - mean_absolute_error: 4110.9204 - root_mean_squared_error: 5711.3008 - val_loss: 3462897.5000 - val_mean_absolute_error: 1445.1635 - val_root_mean_squared_error: 1860.8862
# Epoch 38/100
# 390/390 [==============================] - 2s 4ms/step - loss: 32072140.0000 - mean_absolute_error: 4083.8938 - root_mean_squared_error: 5663.2271 - val_loss: 2376029.7500 - val_mean_absolute_error: 1156.3469 - val_root_mean_squared_error: 1541.4375
# Epoch 39/100
# 390/390 [==============================] - 2s 4ms/step - loss: 33050522.0000 - mean_absolute_error: 4120.7173 - root_mean_squared_error: 5748.9585 - val_loss: 2381657.7500 - val_mean_absolute_error: 1147.7253 - val_root_mean_squared_error: 1543.2621
# Epoch 40/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32889222.0000 - mean_absolute_error: 4097.4976 - root_mean_squared_error: 5734.9126 - val_loss: 2306218.0000 - val_mean_absolute_error: 1120.1157 - val_root_mean_squared_error: 1518.6238
# Epoch 41/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32794612.0000 - mean_absolute_error: 4127.3242 - root_mean_squared_error: 5726.6582 - val_loss: 1910261.0000 - val_mean_absolute_error: 1024.0629 - val_root_mean_squared_error: 1382.1219
# Epoch 42/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32272668.0000 - mean_absolute_error: 4090.8779 - root_mean_squared_error: 5680.9038 - val_loss: 3106139.7500 - val_mean_absolute_error: 1354.7166 - val_root_mean_squared_error: 1762.4244
# Epoch 43/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33439178.0000 - mean_absolute_error: 4182.4009 - root_mean_squared_error: 5782.6616 - val_loss: 2470941.0000 - val_mean_absolute_error: 1160.5353 - val_root_mean_squared_error: 1571.9227
# Epoch 44/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32260476.0000 - mean_absolute_error: 4072.9087 - root_mean_squared_error: 5679.8306 - val_loss: 2914125.0000 - val_mean_absolute_error: 1307.1777 - val_root_mean_squared_error: 1707.0808
# Epoch 45/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31357644.0000 - mean_absolute_error: 4029.7773 - root_mean_squared_error: 5599.7896 - val_loss: 3157033.0000 - val_mean_absolute_error: 1366.5575 - val_root_mean_squared_error: 1776.8042
# Epoch 46/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32755620.0000 - mean_absolute_error: 4120.2046 - root_mean_squared_error: 5723.2524 - val_loss: 3923175.5000 - val_mean_absolute_error: 1549.2068 - val_root_mean_squared_error: 1980.7008
# Epoch 47/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32617302.0000 - mean_absolute_error: 4097.2651 - root_mean_squared_error: 5711.1558 - val_loss: 4333033.0000 - val_mean_absolute_error: 1672.7592 - val_root_mean_squared_error: 2081.5938
# Epoch 48/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33142854.0000 - mean_absolute_error: 4137.4526 - root_mean_squared_error: 5756.9829 - val_loss: 2672502.5000 - val_mean_absolute_error: 1240.5720 - val_root_mean_squared_error: 1634.7791
# Epoch 49/100
# 390/390 [==============================] - 1s 4ms/step - loss: 31479830.0000 - mean_absolute_error: 4057.3750 - root_mean_squared_error: 5610.6890 - val_loss: 2245864.2500 - val_mean_absolute_error: 1131.0421 - val_root_mean_squared_error: 1498.6207
# Epoch 50/100
# 390/390 [==============================] - 2s 4ms/step - loss: 33689556.0000 - mean_absolute_error: 4154.0552 - root_mean_squared_error: 5804.2705 - val_loss: 1995389.3750 - val_mean_absolute_error: 1044.3223 - val_root_mean_squared_error: 1412.5825
# Epoch 51/100
# 390/390 [==============================] - 1s 4ms/step - loss: 33023406.0000 - mean_absolute_error: 4099.2412 - root_mean_squared_error: 5746.5996 - val_loss: 3506110.2500 - val_mean_absolute_error: 1456.0375 - val_root_mean_squared_error: 1872.4611
# Epoch 52/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32967894.0000 - mean_absolute_error: 4109.1782 - root_mean_squared_error: 5741.7676 - val_loss: 2597853.2500 - val_mean_absolute_error: 1217.6115 - val_root_mean_squared_error: 1611.7858
# Epoch 53/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32082682.0000 - mean_absolute_error: 4077.3320 - root_mean_squared_error: 5664.1577 - val_loss: 2529265.2500 - val_mean_absolute_error: 1195.5299 - val_root_mean_squared_error: 1590.3663
# Epoch 54/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32270998.0000 - mean_absolute_error: 4097.3628 - root_mean_squared_error: 5680.7568 - val_loss: 2974753.0000 - val_mean_absolute_error: 1299.0320 - val_root_mean_squared_error: 1724.7472
# Epoch 55/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32366802.0000 - mean_absolute_error: 4117.6294 - root_mean_squared_error: 5689.1831 - val_loss: 3536740.2500 - val_mean_absolute_error: 1453.5354 - val_root_mean_squared_error: 1880.6223
# Epoch 56/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33706480.0000 - mean_absolute_error: 4142.2695 - root_mean_squared_error: 5805.7280 - val_loss: 3145936.5000 - val_mean_absolute_error: 1385.7401 - val_root_mean_squared_error: 1773.6788
# Epoch 57/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33013504.0000 - mean_absolute_error: 4123.9604 - root_mean_squared_error: 5745.7378 - val_loss: 2630997.2500 - val_mean_absolute_error: 1229.4062 - val_root_mean_squared_error: 1622.0349
# Epoch 58/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32107478.0000 - mean_absolute_error: 4078.1128 - root_mean_squared_error: 5666.3462 - val_loss: 2596743.0000 - val_mean_absolute_error: 1204.7623 - val_root_mean_squared_error: 1611.4413
# Epoch 59/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32587984.0000 - mean_absolute_error: 4078.9661 - root_mean_squared_error: 5708.5884 - val_loss: 1872685.3750 - val_mean_absolute_error: 1024.0858 - val_root_mean_squared_error: 1368.4609
# Epoch 60/100
# 390/390 [==============================] - 2s 4ms/step - loss: 31944024.0000 - mean_absolute_error: 4062.4319 - root_mean_squared_error: 5651.9043 - val_loss: 2981742.5000 - val_mean_absolute_error: 1322.1116 - val_root_mean_squared_error: 1726.7723
# Epoch 61/100
# 390/390 [==============================] - 2s 4ms/step - loss: 33336020.0000 - mean_absolute_error: 4137.3667 - root_mean_squared_error: 5773.7354 - val_loss: 2937315.5000 - val_mean_absolute_error: 1305.7078 - val_root_mean_squared_error: 1713.8599
# Epoch 62/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32504988.0000 - mean_absolute_error: 4086.0151 - root_mean_squared_error: 5701.3145 - val_loss: 2612220.5000 - val_mean_absolute_error: 1222.7207 - val_root_mean_squared_error: 1616.2366
# Epoch 63/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31715154.0000 - mean_absolute_error: 4053.1072 - root_mean_squared_error: 5631.6211 - val_loss: 1949550.7500 - val_mean_absolute_error: 1054.6642 - val_root_mean_squared_error: 1396.2632
# Epoch 64/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32391950.0000 - mean_absolute_error: 4090.2761 - root_mean_squared_error: 5691.3926 - val_loss: 2360632.2500 - val_mean_absolute_error: 1152.1211 - val_root_mean_squared_error: 1536.4349
# Epoch 65/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32995252.0000 - mean_absolute_error: 4125.0957 - root_mean_squared_error: 5744.1494 - val_loss: 3071015.0000 - val_mean_absolute_error: 1324.3734 - val_root_mean_squared_error: 1752.4312
# Epoch 66/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31880010.0000 - mean_absolute_error: 4053.8481 - root_mean_squared_error: 5646.2388 - val_loss: 3170146.2500 - val_mean_absolute_error: 1349.2178 - val_root_mean_squared_error: 1780.4905
# Epoch 67/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33065528.0000 - mean_absolute_error: 4113.9238 - root_mean_squared_error: 5750.2632 - val_loss: 2382903.5000 - val_mean_absolute_error: 1148.3929 - val_root_mean_squared_error: 1543.6656
# Epoch 68/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32536524.0000 - mean_absolute_error: 4084.5627 - root_mean_squared_error: 5704.0796 - val_loss: 2974723.2500 - val_mean_absolute_error: 1308.5817 - val_root_mean_squared_error: 1724.7386
# Epoch 69/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32111840.0000 - mean_absolute_error: 4063.8293 - root_mean_squared_error: 5666.7310 - val_loss: 3533537.2500 - val_mean_absolute_error: 1463.3601 - val_root_mean_squared_error: 1879.7705
# Epoch 70/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31415568.0000 - mean_absolute_error: 4051.2280 - root_mean_squared_error: 5604.9595 - val_loss: 2516029.2500 - val_mean_absolute_error: 1183.7480 - val_root_mean_squared_error: 1586.1996
# Epoch 71/100
# 390/390 [==============================] - 2s 4ms/step - loss: 32280538.0000 - mean_absolute_error: 4086.6538 - root_mean_squared_error: 5681.5962 - val_loss: 2651964.0000 - val_mean_absolute_error: 1227.0695 - val_root_mean_squared_error: 1628.4852
# Epoch 72/100
# 390/390 [==============================] - 2s 5ms/step - loss: 32704210.0000 - mean_absolute_error: 4083.8440 - root_mean_squared_error: 5718.7593 - val_loss: 3130876.5000 - val_mean_absolute_error: 1376.4576 - val_root_mean_squared_error: 1769.4283
# Epoch 73/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32595370.0000 - mean_absolute_error: 4072.9026 - root_mean_squared_error: 5709.2354 - val_loss: 3730415.7500 - val_mean_absolute_error: 1502.4501 - val_root_mean_squared_error: 1931.4285
# Epoch 74/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32462834.0000 - mean_absolute_error: 4059.5562 - root_mean_squared_error: 5697.6167 - val_loss: 3086473.2500 - val_mean_absolute_error: 1363.5109 - val_root_mean_squared_error: 1756.8362
# Epoch 75/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32323446.0000 - mean_absolute_error: 4093.8291 - root_mean_squared_error: 5685.3711 - val_loss: 3206734.5000 - val_mean_absolute_error: 1379.8925 - val_root_mean_squared_error: 1790.7357
# Epoch 76/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32293134.0000 - mean_absolute_error: 4095.2837 - root_mean_squared_error: 5682.7046 - val_loss: 2007384.8750 - val_mean_absolute_error: 1038.3317 - val_root_mean_squared_error: 1416.8221
# Epoch 77/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32068108.0000 - mean_absolute_error: 4075.4221 - root_mean_squared_error: 5662.8711 - val_loss: 3013679.2500 - val_mean_absolute_error: 1341.3403 - val_root_mean_squared_error: 1735.9951
# Epoch 78/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32522066.0000 - mean_absolute_error: 4072.0713 - root_mean_squared_error: 5702.8120 - val_loss: 3231966.2500 - val_mean_absolute_error: 1393.5920 - val_root_mean_squared_error: 1797.7670
# Epoch 79/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32288568.0000 - mean_absolute_error: 4108.3657 - root_mean_squared_error: 5682.3032 - val_loss: 1977589.3750 - val_mean_absolute_error: 1052.3870 - val_root_mean_squared_error: 1406.2679
# Epoch 80/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32261724.0000 - mean_absolute_error: 4069.5188 - root_mean_squared_error: 5679.9404 - val_loss: 3376689.2500 - val_mean_absolute_error: 1425.7638 - val_root_mean_squared_error: 1837.5770
# Epoch 81/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33019146.0000 - mean_absolute_error: 4093.9434 - root_mean_squared_error: 5746.2290 - val_loss: 2486305.2500 - val_mean_absolute_error: 1192.9365 - val_root_mean_squared_error: 1576.8022
# Epoch 82/100
# 390/390 [==============================] - 1s 4ms/step - loss: 31927086.0000 - mean_absolute_error: 4049.8584 - root_mean_squared_error: 5650.4058 - val_loss: 3012505.5000 - val_mean_absolute_error: 1324.0521 - val_root_mean_squared_error: 1735.6571
# Epoch 83/100
# 390/390 [==============================] - 2s 4ms/step - loss: 33283784.0000 - mean_absolute_error: 4131.5874 - root_mean_squared_error: 5769.2100 - val_loss: 2813340.7500 - val_mean_absolute_error: 1272.4047 - val_root_mean_squared_error: 1677.3016
# Epoch 84/100
# 390/390 [==============================] - 2s 4ms/step - loss: 32883476.0000 - mean_absolute_error: 4114.2051 - root_mean_squared_error: 5734.4116 - val_loss: 2789023.5000 - val_mean_absolute_error: 1272.4764 - val_root_mean_squared_error: 1670.0370
# Epoch 85/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32582930.0000 - mean_absolute_error: 4065.0593 - root_mean_squared_error: 5708.1460 - val_loss: 2691427.5000 - val_mean_absolute_error: 1268.4526 - val_root_mean_squared_error: 1640.5571
# Epoch 86/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32187316.0000 - mean_absolute_error: 4096.3320 - root_mean_squared_error: 5673.3867 - val_loss: 3713131.5000 - val_mean_absolute_error: 1507.2317 - val_root_mean_squared_error: 1926.9487
# Epoch 87/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31079514.0000 - mean_absolute_error: 4013.5715 - root_mean_squared_error: 5574.9004 - val_loss: 3180028.0000 - val_mean_absolute_error: 1381.1899 - val_root_mean_squared_error: 1783.2633
# Epoch 88/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32617072.0000 - mean_absolute_error: 4104.4902 - root_mean_squared_error: 5711.1357 - val_loss: 2688542.0000 - val_mean_absolute_error: 1246.1827 - val_root_mean_squared_error: 1639.6774
# Epoch 89/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32605280.0000 - mean_absolute_error: 4047.4958 - root_mean_squared_error: 5710.1035 - val_loss: 2924104.5000 - val_mean_absolute_error: 1313.7506 - val_root_mean_squared_error: 1710.0013
# Epoch 90/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31899082.0000 - mean_absolute_error: 4054.1443 - root_mean_squared_error: 5647.9272 - val_loss: 2462838.5000 - val_mean_absolute_error: 1188.8768 - val_root_mean_squared_error: 1569.3434
# Epoch 91/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32356404.0000 - mean_absolute_error: 4067.5244 - root_mean_squared_error: 5688.2690 - val_loss: 2691418.5000 - val_mean_absolute_error: 1253.2644 - val_root_mean_squared_error: 1640.5543
# Epoch 92/100
# 390/390 [==============================] - 1s 3ms/step - loss: 34064528.0000 - mean_absolute_error: 4163.7095 - root_mean_squared_error: 5836.4824 - val_loss: 2717303.0000 - val_mean_absolute_error: 1263.6578 - val_root_mean_squared_error: 1648.4244
# Epoch 93/100
# 390/390 [==============================] - 2s 4ms/step - loss: 31712334.0000 - mean_absolute_error: 4048.5342 - root_mean_squared_error: 5631.3706 - val_loss: 1773626.7500 - val_mean_absolute_error: 997.3632 - val_root_mean_squared_error: 1331.7758
# Epoch 94/100
# 390/390 [==============================] - 2s 4ms/step - loss: 32626972.0000 - mean_absolute_error: 4108.0361 - root_mean_squared_error: 5712.0024 - val_loss: 2834502.5000 - val_mean_absolute_error: 1299.7069 - val_root_mean_squared_error: 1683.5980
# Epoch 95/100
# 390/390 [==============================] - 1s 4ms/step - loss: 32828252.0000 - mean_absolute_error: 4115.8105 - root_mean_squared_error: 5729.5942 - val_loss: 2310699.7500 - val_mean_absolute_error: 1142.9225 - val_root_mean_squared_error: 1520.0986
# Epoch 96/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33164260.0000 - mean_absolute_error: 4121.7896 - root_mean_squared_error: 5758.8418 - val_loss: 1912202.7500 - val_mean_absolute_error: 1018.3402 - val_root_mean_squared_error: 1382.8242
# Epoch 97/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32052086.0000 - mean_absolute_error: 4068.2959 - root_mean_squared_error: 5661.4561 - val_loss: 3126683.5000 - val_mean_absolute_error: 1362.4742 - val_root_mean_squared_error: 1768.2430
# Epoch 98/100
# 390/390 [==============================] - 1s 3ms/step - loss: 31949470.0000 - mean_absolute_error: 4063.5972 - root_mean_squared_error: 5652.3862 - val_loss: 3407992.0000 - val_mean_absolute_error: 1442.1530 - val_root_mean_squared_error: 1846.0747
# Epoch 99/100
# 390/390 [==============================] - 1s 3ms/step - loss: 32602170.0000 - mean_absolute_error: 4082.8057 - root_mean_squared_error: 5709.8311 - val_loss: 2730727.2500 - val_mean_absolute_error: 1264.4852 - val_root_mean_squared_error: 1652.4912
# Epoch 100/100
# 390/390 [==============================] - 1s 3ms/step - loss: 33581044.0000 - mean_absolute_error: 4155.1328 - root_mean_squared_error: 5794.9155 - val_loss: 2126081.0000 - val_mean_absolute_error: 1101.6073 - val_root_mean_squared_error: 1458.1088

# %%
# Model Sequential
model_3 = Sequential()

# Hidden layers
model_3.add(Dense(37, input_dim = X_train_tf.shape[1], activation='relu')),
BatchNormalization(),
model_3.add(Dropout(.2)),
model_3.add(Dense(25, activation='relu')),
BatchNormalization(),
model_3.add(Dropout(.2)),
model_3.add(Dense(10, activation='relu')),
BatchNormalization(),
model_3.add(Dropout(.2)),

# Output layer
model_3.add(Dense(1, activation='linear'))

# Compile the model
model_3.compile(loss='mse', optimizer='adam', metrics=[metrics.MeanAbsoluteError(), metrics.RootMeanSquaredError()])

# Fit the model
history = model_3.fit(X_train_tf, y_train,
                    validation_data = (X_test_tf, y_test),
                    epochs = 100,
                    batch_size = 32)
# Out:
# Epoch 1/100
# 390/390 [==============================] - 3s 4ms/step - loss: 545779712.0000 - mean_absolute_error: 20330.7148 - root_mean_squared_error: 23361.9277 - val_loss: 247382832.0000 - val_mean_absolute_error: 12859.2979 - val_root_mean_squared_error: 15728.4082
# Epoch 2/100
# 390/390 [==============================] - 1s 3ms/step - loss: 104279432.0000 - mean_absolute_error: 7762.2764 - root_mean_squared_error: 10211.7305 - val_loss: 33375276.0000 - val_mean_absolute_error: 4524.4258 - val_root_mean_squared_error: 5777.1338
# Epoch 3/100
# 390/390 [==============================] - 1s 3ms/step - loss: 69291016.0000 - mean_absolute_error: 6341.1631 - root_mean_squared_error: 8324.1221 - val_loss: 21255610.0000 - val_mean_absolute_error: 3607.9119 - val_root_mean_squared_error: 4610.3809
# Epoch 4/100
# 390/390 [==============================] - 1s 3ms/step - loss: 61572824.0000 - mean_absolute_error: 5893.0356 - root_mean_squared_error: 7846.8354 - val_loss: 15388710.0000 - val_mean_absolute_error: 3061.5977 - val_root_mean_squared_error: 3922.8447
# Epoch 5/100
# 390/390 [==============================] - 1s 3ms/step - loss: 55173088.0000 - mean_absolute_error: 5449.3486 - root_mean_squared_error: 7427.8589 - val_loss: 9359186.0000 - val_mean_absolute_error: 2371.1670 - val_root_mean_squared_error: 3059.2786
# Epoch 6/100
# 390/390 [==============================] - 1s 3ms/step - loss: 51416232.0000 - mean_absolute_error: 5240.4038 - root_mean_squared_error: 7170.5112 - val_loss: 7596368.5000 - val_mean_absolute_error: 2126.6821 - val_root_mean_squared_error: 2756.1511
# Epoch 7/100
# 390/390 [==============================] - 1s 4ms/step - loss: 49254984.0000 - mean_absolute_error: 5058.8716 - root_mean_squared_error: 7018.1895 - val_loss: 6338231.0000 - val_mean_absolute_error: 1947.4193 - val_root_mean_squared_error: 2517.5845
# Epoch 8/100
# 390/390 [==============================] - 2s 5ms/step - loss: 50046388.0000 - mean_absolute_error: 5114.2417 - root_mean_squared_error: 7074.3472 - val_loss: 5866978.0000 - val_mean_absolute_error: 1902.9099 - val_root_mean_squared_error: 2422.1846
# Epoch 9/100
# 390/390 [==============================] - 2s 5ms/step - loss: 48709816.0000 - mean_absolute_error: 4991.4277 - root_mean_squared_error: 6979.2417 - val_loss: 5848776.0000 - val_mean_absolute_error: 1932.3516 - val_root_mean_squared_error: 2418.4243
# Epoch 10/100
# 390/390 [==============================] - 1s 4ms/step - loss: 49625952.0000 - mean_absolute_error: 5020.2197 - root_mean_squared_error: 7044.5688 - val_loss: 4854056.5000 - val_mean_absolute_error: 1730.9718 - val_root_mean_squared_error: 2203.1924
# Epoch 11/100
# 390/390 [==============================] - 1s 3ms/step - loss: 49111396.0000 - mean_absolute_error: 5013.5498 - root_mean_squared_error: 7007.9521 - val_loss: 4571625.0000 - val_mean_absolute_error: 1687.3521 - val_root_mean_squared_error: 2138.1360
# Epoch 12/100
# 390/390 [==============================] - 1s 3ms/step - loss: 49353268.0000 - mean_absolute_error: 5022.0537 - root_mean_squared_error: 7025.1880 - val_loss: 5058780.0000 - val_mean_absolute_error: 1807.5521 - val_root_mean_squared_error: 2249.1731
# Epoch 13/100
# 390/390 [==============================] - 1s 3ms/step - loss: 49133248.0000 - mean_absolute_error: 5020.3374 - root_mean_squared_error: 7009.5112 - val_loss: 5385544.5000 - val_mean_absolute_error: 1858.2367 - val_root_mean_squared_error: 2320.6775
# Epoch 14/100
# 390/390 [==============================] - 1s 3ms/step - loss: 48867380.0000 - mean_absolute_error: 5021.5703 - root_mean_squared_error: 6990.5205 - val_loss: 5074597.0000 - val_mean_absolute_error: 1810.1660 - val_root_mean_squared_error: 2252.6865
# Epoch 15/100
# 390/390 [==============================] - 1s 3ms/step - loss: 50229844.0000 - mean_absolute_error: 5069.0933 - root_mean_squared_error: 7087.3018 - val_loss: 3456860.2500 - val_mean_absolute_error: 1421.2589 - val_root_mean_squared_error: 1859.2633
# Epoch 16/100
# 390/390 [==============================] - 1s 3ms/step - loss: 48214692.0000 - mean_absolute_error: 4974.2510 - root_mean_squared_error: 6943.6802 - val_loss: 5267944.0000 - val_mean_absolute_error: 1811.4949 - val_root_mean_squared_error: 2295.2002
# Epoch 17/100
# 390/390 [==============================] - 1s 3ms/step - loss: 48968456.0000 - mean_absolute_error: 5029.9575 - root_mean_squared_error: 6997.7466 - val_loss: 6145923.5000 - val_mean_absolute_error: 2021.1736 - val_root_mean_squared_error: 2479.0974
# Epoch 18/100
# 390/390 [==============================] - 2s 5ms/step - loss: 49531832.0000 - mean_absolute_error: 5015.9922 - root_mean_squared_error: 7037.8853 - val_loss: 5815233.0000 - val_mean_absolute_error: 1938.1685 - val_root_mean_squared_error: 2411.4795
# Epoch 19/100
# 390/390 [==============================] - 2s 5ms/step - loss: 48720644.0000 - mean_absolute_error: 4967.7812 - root_mean_squared_error: 6980.0176 - val_loss: 5061897.0000 - val_mean_absolute_error: 1774.8583 - val_root_mean_squared_error: 2249.8660
# Epoch 20/100
# 390/390 [==============================] - 1s 3ms/step - loss: 49961896.0000 - mean_absolute_error: 5025.8315 - root_mean_squared_error: 7068.3730 - val_loss: 4165856.7500 - val_mean_absolute_error: 1603.6650 - val_root_mean_squared_error: 2041.0431
# Epoch 21/100
# 390/390 [==============================] - 1s 3ms/step - loss: 47140256.0000 - mean_absolute_error: 4955.4668 - root_mean_squared_error: 6865.8760 - val_loss: 4343969.0000 - val_mean_absolute_error: 1631.7598 - val_root_mean_squared_error: 2084.2190
# Epoch 22/100
# 390/390 [==============================] - 1s 3ms/step - loss: 48777040.0000 - mean_absolute_error: 5014.1406 - root_mean_squared_error: 6984.0562 - val_loss: 4464905.0000 - val_mean_absolute_error: 1660.9353 - val_root_mean_squared_error: 2113.0322
# Epoch 23/100
# 390/390 [==============================] - 1s 3ms/step - loss: 45222872.0000 - mean_absolute_error: 4811.5425 - root_mean_squared_error: 6724.7954 - val_loss: 2921348.7500 - val_mean_absolute_error: 1310.2034 - val_root_mean_squared_error: 1709.1953
# Epoch 24/100
# 390/390 [==============================] - 1s 3ms/step - loss: 44645284.0000 - mean_absolute_error: 4758.7261 - root_mean_squared_error: 6681.7129 - val_loss: 5312981.0000 - val_mean_absolute_error: 1872.1617 - val_root_mean_squared_error: 2304.9905
# Epoch 25/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42031404.0000 - mean_absolute_error: 4644.4580 - root_mean_squared_error: 6483.1631 - val_loss: 4118706.0000 - val_mean_absolute_error: 1604.1545 - val_root_mean_squared_error: 2029.4596
# Epoch 26/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41897692.0000 - mean_absolute_error: 4634.7124 - root_mean_squared_error: 6472.8428 - val_loss: 3252702.2500 - val_mean_absolute_error: 1402.1143 - val_root_mean_squared_error: 1803.5249
# Epoch 27/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42737920.0000 - mean_absolute_error: 4654.2700 - root_mean_squared_error: 6537.4248 - val_loss: 3517392.0000 - val_mean_absolute_error: 1447.8518 - val_root_mean_squared_error: 1875.4712
# Epoch 28/100
# 390/390 [==============================] - 2s 4ms/step - loss: 42575272.0000 - mean_absolute_error: 4663.8442 - root_mean_squared_error: 6524.9731 - val_loss: 3423518.0000 - val_mean_absolute_error: 1407.2836 - val_root_mean_squared_error: 1850.2751
# Epoch 29/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40868448.0000 - mean_absolute_error: 4581.2842 - root_mean_squared_error: 6392.8433 - val_loss: 3537833.2500 - val_mean_absolute_error: 1443.7501 - val_root_mean_squared_error: 1880.9128
# Epoch 30/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41732268.0000 - mean_absolute_error: 4630.9307 - root_mean_squared_error: 6460.0518 - val_loss: 3956039.2500 - val_mean_absolute_error: 1567.3369 - val_root_mean_squared_error: 1988.9795
# Epoch 31/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41197148.0000 - mean_absolute_error: 4591.6436 - root_mean_squared_error: 6418.5005 - val_loss: 3852722.5000 - val_mean_absolute_error: 1536.2468 - val_root_mean_squared_error: 1962.8353
# Epoch 32/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42575108.0000 - mean_absolute_error: 4659.1973 - root_mean_squared_error: 6524.9604 - val_loss: 2744730.5000 - val_mean_absolute_error: 1245.9365 - val_root_mean_squared_error: 1656.7228
# Epoch 33/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40392512.0000 - mean_absolute_error: 4523.4048 - root_mean_squared_error: 6355.5103 - val_loss: 4758908.5000 - val_mean_absolute_error: 1758.6206 - val_root_mean_squared_error: 2181.4922
# Epoch 34/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42516488.0000 - mean_absolute_error: 4666.3203 - root_mean_squared_error: 6520.4668 - val_loss: 3855326.0000 - val_mean_absolute_error: 1553.1154 - val_root_mean_squared_error: 1963.4984
# Epoch 35/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41916096.0000 - mean_absolute_error: 4630.3940 - root_mean_squared_error: 6474.2642 - val_loss: 4781522.0000 - val_mean_absolute_error: 1737.6440 - val_root_mean_squared_error: 2186.6692
# Epoch 36/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41400512.0000 - mean_absolute_error: 4594.3789 - root_mean_squared_error: 6434.3228 - val_loss: 4144558.0000 - val_mean_absolute_error: 1602.4694 - val_root_mean_squared_error: 2035.8187
# Epoch 37/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40931608.0000 - mean_absolute_error: 4592.1621 - root_mean_squared_error: 6397.7812 - val_loss: 3724855.7500 - val_mean_absolute_error: 1491.2358 - val_root_mean_squared_error: 1929.9885
# Epoch 38/100
# 390/390 [==============================] - 2s 4ms/step - loss: 40601044.0000 - mean_absolute_error: 4573.9263 - root_mean_squared_error: 6371.8950 - val_loss: 4391662.5000 - val_mean_absolute_error: 1642.4515 - val_root_mean_squared_error: 2095.6294
# Epoch 39/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40785288.0000 - mean_absolute_error: 4612.3628 - root_mean_squared_error: 6386.3359 - val_loss: 3601152.2500 - val_mean_absolute_error: 1467.6411 - val_root_mean_squared_error: 1897.6702
# Epoch 40/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42946944.0000 - mean_absolute_error: 4680.1714 - root_mean_squared_error: 6553.3916 - val_loss: 3499833.0000 - val_mean_absolute_error: 1459.2959 - val_root_mean_squared_error: 1870.7841
# Epoch 41/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41378456.0000 - mean_absolute_error: 4602.6104 - root_mean_squared_error: 6432.6089 - val_loss: 4173270.5000 - val_mean_absolute_error: 1610.8108 - val_root_mean_squared_error: 2042.8584
# Epoch 42/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40842820.0000 - mean_absolute_error: 4549.1436 - root_mean_squared_error: 6390.8389 - val_loss: 4349337.0000 - val_mean_absolute_error: 1638.9147 - val_root_mean_squared_error: 2085.5063
# Epoch 43/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41183760.0000 - mean_absolute_error: 4574.5264 - root_mean_squared_error: 6417.4575 - val_loss: 3644656.2500 - val_mean_absolute_error: 1491.7356 - val_root_mean_squared_error: 1909.0983
# Epoch 44/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40789944.0000 - mean_absolute_error: 4565.1226 - root_mean_squared_error: 6386.7007 - val_loss: 2762675.0000 - val_mean_absolute_error: 1246.9563 - val_root_mean_squared_error: 1662.1296
# Epoch 45/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41762640.0000 - mean_absolute_error: 4603.2314 - root_mean_squared_error: 6462.4019 - val_loss: 3445306.2500 - val_mean_absolute_error: 1440.9399 - val_root_mean_squared_error: 1856.1536
# Epoch 46/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41404104.0000 - mean_absolute_error: 4593.7134 - root_mean_squared_error: 6434.6021 - val_loss: 4476791.5000 - val_mean_absolute_error: 1678.5129 - val_root_mean_squared_error: 2115.8430
# Epoch 47/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41445304.0000 - mean_absolute_error: 4585.0254 - root_mean_squared_error: 6437.8027 - val_loss: 4324199.5000 - val_mean_absolute_error: 1660.9302 - val_root_mean_squared_error: 2079.4709
# Epoch 48/100
# 390/390 [==============================] - 2s 4ms/step - loss: 41116844.0000 - mean_absolute_error: 4571.2852 - root_mean_squared_error: 6412.2417 - val_loss: 3653126.2500 - val_mean_absolute_error: 1483.5605 - val_root_mean_squared_error: 1911.3153
# Epoch 49/100
# 390/390 [==============================] - 2s 5ms/step - loss: 41392372.0000 - mean_absolute_error: 4611.2686 - root_mean_squared_error: 6433.6904 - val_loss: 2563205.2500 - val_mean_absolute_error: 1196.6447 - val_root_mean_squared_error: 1601.0013
# Epoch 50/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40827668.0000 - mean_absolute_error: 4565.1045 - root_mean_squared_error: 6389.6533 - val_loss: 3810546.7500 - val_mean_absolute_error: 1520.0513 - val_root_mean_squared_error: 1952.0621
# Epoch 51/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41942496.0000 - mean_absolute_error: 4589.6313 - root_mean_squared_error: 6476.3027 - val_loss: 5418212.0000 - val_mean_absolute_error: 1889.1849 - val_root_mean_squared_error: 2327.7053
# Epoch 52/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40328476.0000 - mean_absolute_error: 4534.9707 - root_mean_squared_error: 6350.4707 - val_loss: 3029019.5000 - val_mean_absolute_error: 1329.5599 - val_root_mean_squared_error: 1740.4078
# Epoch 53/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41114328.0000 - mean_absolute_error: 4601.2866 - root_mean_squared_error: 6412.0454 - val_loss: 2487677.5000 - val_mean_absolute_error: 1202.4056 - val_root_mean_squared_error: 1577.2373
# Epoch 54/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42539444.0000 - mean_absolute_error: 4641.3154 - root_mean_squared_error: 6522.2271 - val_loss: 3380548.7500 - val_mean_absolute_error: 1420.6334 - val_root_mean_squared_error: 1838.6268
# Epoch 55/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41459480.0000 - mean_absolute_error: 4579.3882 - root_mean_squared_error: 6438.9038 - val_loss: 2043546.5000 - val_mean_absolute_error: 1070.8746 - val_root_mean_squared_error: 1429.5266
# Epoch 56/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41661752.0000 - mean_absolute_error: 4587.7036 - root_mean_squared_error: 6454.5913 - val_loss: 3762732.2500 - val_mean_absolute_error: 1535.1100 - val_root_mean_squared_error: 1939.7764
# Epoch 57/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41637812.0000 - mean_absolute_error: 4610.2974 - root_mean_squared_error: 6452.7368 - val_loss: 2938858.2500 - val_mean_absolute_error: 1306.2791 - val_root_mean_squared_error: 1714.3098
# Epoch 58/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41032096.0000 - mean_absolute_error: 4531.0981 - root_mean_squared_error: 6405.6299 - val_loss: 2948261.2500 - val_mean_absolute_error: 1309.2859 - val_root_mean_squared_error: 1717.0502
# Epoch 59/100
# 390/390 [==============================] - 2s 4ms/step - loss: 41771024.0000 - mean_absolute_error: 4624.8496 - root_mean_squared_error: 6463.0508 - val_loss: 4309622.5000 - val_mean_absolute_error: 1650.4088 - val_root_mean_squared_error: 2075.9631
# Epoch 60/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40358228.0000 - mean_absolute_error: 4530.7710 - root_mean_squared_error: 6352.8125 - val_loss: 2868280.2500 - val_mean_absolute_error: 1306.6119 - val_root_mean_squared_error: 1693.5997
# Epoch 61/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40907192.0000 - mean_absolute_error: 4565.3135 - root_mean_squared_error: 6395.8730 - val_loss: 5118440.0000 - val_mean_absolute_error: 1818.6957 - val_root_mean_squared_error: 2262.3970
# Epoch 62/100
# 390/390 [==============================] - 1s 3ms/step - loss: 42120696.0000 - mean_absolute_error: 4578.6465 - root_mean_squared_error: 6490.0459 - val_loss: 3539089.5000 - val_mean_absolute_error: 1446.4783 - val_root_mean_squared_error: 1881.2468
# Epoch 63/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40625936.0000 - mean_absolute_error: 4554.3794 - root_mean_squared_error: 6373.8477 - val_loss: 3422649.5000 - val_mean_absolute_error: 1443.9695 - val_root_mean_squared_error: 1850.0404
# Epoch 64/100
# 390/390 [==============================] - 1s 3ms/step - loss: 39968052.0000 - mean_absolute_error: 4520.7202 - root_mean_squared_error: 6322.0293 - val_loss: 4565778.5000 - val_mean_absolute_error: 1700.2698 - val_root_mean_squared_error: 2136.7683
# Epoch 65/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41566708.0000 - mean_absolute_error: 4603.8701 - root_mean_squared_error: 6447.2246 - val_loss: 3963786.7500 - val_mean_absolute_error: 1555.1890 - val_root_mean_squared_error: 1990.9261
# Epoch 66/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40829544.0000 - mean_absolute_error: 4556.5845 - root_mean_squared_error: 6389.7998 - val_loss: 2959977.0000 - val_mean_absolute_error: 1291.2399 - val_root_mean_squared_error: 1720.4584
# Epoch 67/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40711596.0000 - mean_absolute_error: 4551.3809 - root_mean_squared_error: 6380.5640 - val_loss: 3620210.5000 - val_mean_absolute_error: 1492.2561 - val_root_mean_squared_error: 1902.6851
# Epoch 68/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40715760.0000 - mean_absolute_error: 4552.3052 - root_mean_squared_error: 6380.8901 - val_loss: 5023431.0000 - val_mean_absolute_error: 1803.8153 - val_root_mean_squared_error: 2241.3013
# Epoch 69/100
# 390/390 [==============================] - 2s 4ms/step - loss: 40789816.0000 - mean_absolute_error: 4566.4849 - root_mean_squared_error: 6386.6904 - val_loss: 3537824.2500 - val_mean_absolute_error: 1475.0046 - val_root_mean_squared_error: 1880.9105
# Epoch 70/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40993800.0000 - mean_absolute_error: 4586.3706 - root_mean_squared_error: 6402.6401 - val_loss: 2832199.5000 - val_mean_absolute_error: 1276.8307 - val_root_mean_squared_error: 1682.9139
# Epoch 71/100
# 390/390 [==============================] - 1s 4ms/step - loss: 40781676.0000 - mean_absolute_error: 4551.9829 - root_mean_squared_error: 6386.0532 - val_loss: 3590461.5000 - val_mean_absolute_error: 1476.8477 - val_root_mean_squared_error: 1894.8513
# Epoch 72/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40470944.0000 - mean_absolute_error: 4557.8022 - root_mean_squared_error: 6361.6777 - val_loss: 4153015.2500 - val_mean_absolute_error: 1598.0131 - val_root_mean_squared_error: 2037.8948
# Epoch 73/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41106664.0000 - mean_absolute_error: 4553.6748 - root_mean_squared_error: 6411.4478 - val_loss: 3264567.7500 - val_mean_absolute_error: 1410.0703 - val_root_mean_squared_error: 1806.8115
# Epoch 74/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41014784.0000 - mean_absolute_error: 4556.8076 - root_mean_squared_error: 6404.2788 - val_loss: 3155697.7500 - val_mean_absolute_error: 1377.6931 - val_root_mean_squared_error: 1776.4283
# Epoch 75/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40681104.0000 - mean_absolute_error: 4568.4385 - root_mean_squared_error: 6378.1738 - val_loss: 2776171.0000 - val_mean_absolute_error: 1252.2681 - val_root_mean_squared_error: 1666.1846
# Epoch 76/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40302728.0000 - mean_absolute_error: 4512.5303 - root_mean_squared_error: 6348.4429 - val_loss: 4357334.5000 - val_mean_absolute_error: 1666.7412 - val_root_mean_squared_error: 2087.4229
# Epoch 77/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40264380.0000 - mean_absolute_error: 4552.3198 - root_mean_squared_error: 6345.4219 - val_loss: 3957330.5000 - val_mean_absolute_error: 1567.8098 - val_root_mean_squared_error: 1989.3041
# Epoch 78/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41886488.0000 - mean_absolute_error: 4624.0752 - root_mean_squared_error: 6471.9771 - val_loss: 2498117.2500 - val_mean_absolute_error: 1182.0458 - val_root_mean_squared_error: 1580.5433
# Epoch 79/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40806880.0000 - mean_absolute_error: 4574.5962 - root_mean_squared_error: 6388.0264 - val_loss: 2809789.0000 - val_mean_absolute_error: 1267.2617 - val_root_mean_squared_error: 1676.2426
# Epoch 80/100
# 390/390 [==============================] - 2s 5ms/step - loss: 40649708.0000 - mean_absolute_error: 4571.2314 - root_mean_squared_error: 6375.7124 - val_loss: 3715909.0000 - val_mean_absolute_error: 1510.4755 - val_root_mean_squared_error: 1927.6693
# Epoch 81/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40840132.0000 - mean_absolute_error: 4557.6309 - root_mean_squared_error: 6390.6284 - val_loss: 3525744.7500 - val_mean_absolute_error: 1463.8361 - val_root_mean_squared_error: 1877.6967
# Epoch 82/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40195560.0000 - mean_absolute_error: 4510.2769 - root_mean_squared_error: 6339.9971 - val_loss: 4259512.5000 - val_mean_absolute_error: 1654.0980 - val_root_mean_squared_error: 2063.8586
# Epoch 83/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41675424.0000 - mean_absolute_error: 4594.9717 - root_mean_squared_error: 6455.6504 - val_loss: 4227761.0000 - val_mean_absolute_error: 1630.2303 - val_root_mean_squared_error: 2056.1521
# Epoch 84/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40239528.0000 - mean_absolute_error: 4556.5723 - root_mean_squared_error: 6343.4634 - val_loss: 2390747.2500 - val_mean_absolute_error: 1168.8807 - val_root_mean_squared_error: 1546.2041
# Epoch 85/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41117656.0000 - mean_absolute_error: 4574.8462 - root_mean_squared_error: 6412.3052 - val_loss: 3934869.5000 - val_mean_absolute_error: 1566.5343 - val_root_mean_squared_error: 1983.6505
# Epoch 86/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41219532.0000 - mean_absolute_error: 4580.5801 - root_mean_squared_error: 6420.2441 - val_loss: 4777458.0000 - val_mean_absolute_error: 1764.1288 - val_root_mean_squared_error: 2185.7397
# Epoch 87/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41545004.0000 - mean_absolute_error: 4570.2666 - root_mean_squared_error: 6445.5415 - val_loss: 3010082.7500 - val_mean_absolute_error: 1317.5796 - val_root_mean_squared_error: 1734.9590
# Epoch 88/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41356832.0000 - mean_absolute_error: 4577.7100 - root_mean_squared_error: 6430.9277 - val_loss: 4203892.0000 - val_mean_absolute_error: 1594.9946 - val_root_mean_squared_error: 2050.3396
# Epoch 89/100
# 390/390 [==============================] - 2s 4ms/step - loss: 40350184.0000 - mean_absolute_error: 4555.3130 - root_mean_squared_error: 6352.1797 - val_loss: 5276304.5000 - val_mean_absolute_error: 1855.0616 - val_root_mean_squared_error: 2297.0208
# Epoch 90/100
# 390/390 [==============================] - 2s 5ms/step - loss: 39654616.0000 - mean_absolute_error: 4501.5459 - root_mean_squared_error: 6297.1909 - val_loss: 4449105.0000 - val_mean_absolute_error: 1669.0265 - val_root_mean_squared_error: 2109.2903
# Epoch 91/100
# 390/390 [==============================] - 1s 4ms/step - loss: 40103708.0000 - mean_absolute_error: 4518.6392 - root_mean_squared_error: 6332.7490 - val_loss: 4918673.0000 - val_mean_absolute_error: 1773.6456 - val_root_mean_squared_error: 2217.8081
# Epoch 92/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41189736.0000 - mean_absolute_error: 4561.9263 - root_mean_squared_error: 6417.9233 - val_loss: 3988315.5000 - val_mean_absolute_error: 1580.1670 - val_root_mean_squared_error: 1997.0768
# Epoch 93/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41275900.0000 - mean_absolute_error: 4566.6377 - root_mean_squared_error: 6424.6323 - val_loss: 4385024.0000 - val_mean_absolute_error: 1683.2747 - val_root_mean_squared_error: 2094.0449
# Epoch 94/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41563088.0000 - mean_absolute_error: 4597.7393 - root_mean_squared_error: 6446.9438 - val_loss: 4793161.0000 - val_mean_absolute_error: 1770.0354 - val_root_mean_squared_error: 2189.3289
# Epoch 95/100
# 390/390 [==============================] - 1s 3ms/step - loss: 40309292.0000 - mean_absolute_error: 4534.0620 - root_mean_squared_error: 6348.9600 - val_loss: 3751447.0000 - val_mean_absolute_error: 1496.9918 - val_root_mean_squared_error: 1936.8652
# Epoch 96/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41174476.0000 - mean_absolute_error: 4576.6475 - root_mean_squared_error: 6416.7339 - val_loss: 2222676.7500 - val_mean_absolute_error: 1120.5874 - val_root_mean_squared_error: 1490.8644
# Epoch 97/100
# 390/390 [==============================] - 1s 3ms/step - loss: 41298488.0000 - mean_absolute_error: 4596.2471 - root_mean_squared_error: 6426.3901 - val_loss: 4298864.5000 - val_mean_absolute_error: 1645.5972 - val_root_mean_squared_error: 2073.3704
# Epoch 98/100
# 390/390 [==============================] - 1s 3ms/step - loss: 39557268.0000 - mean_absolute_error: 4500.9741 - root_mean_squared_error: 6289.4570 - val_loss: 2900054.0000 - val_mean_absolute_error: 1286.9219 - val_root_mean_squared_error: 1702.9545
# Epoch 99/100
# 390/390 [==============================] - 2s 4ms/step - loss: 42258696.0000 - mean_absolute_error: 4593.3550 - root_mean_squared_error: 6500.6689 - val_loss: 3842681.2500 - val_mean_absolute_error: 1544.0923 - val_root_mean_squared_error: 1960.2758
# Epoch 100/100
# 390/390 [==============================] - 2s 5ms/step - loss: 39623700.0000 - mean_absolute_error: 4509.0142 - root_mean_squared_error: 6294.7358 - val_loss: 3143774.7500 - val_mean_absolute_error: 1355.8943 - val_root_mean_squared_error: 1773.0693

# %%
# Define a function to display metrics
def display_metrics(y_true, y_pred, model_name):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)

    print(f'Model: {model_name}')
    print(f'MAE: {mae:.2f}')
    print(f'MSE: {mse:.2f}')
    print(f'RMSE: {rmse:.2f}')
    print(f'R2-Score: {r2:.2f}')
    print()

print('Training set')
# Assuming y_test is a pandas Series
y_train_array = y_train.values.reshape(-1, 1)
# Predict probabilities for each model
ytr_pred_v1 = model_1.predict(X_train_tf).reshape(-1, 1)
ytr_pred_v2 = model_2.predict(X_train_tf).reshape(-1, 1)
ytr_pred_v3 = model_3.predict(X_train_tf).reshape(-1, 1)
# Display metrics for each model
display_metrics(y_train_array, ytr_pred_v1, 'Model v1')
display_metrics(y_train_array, ytr_pred_v2, 'Model v2')
display_metrics(y_train_array, ytr_pred_v3, 'Model v3')

print('Testing set')
# Assuming y_test is a pandas Series
y_test_array = y_test.values.reshape(-1, 1)
# Predict probabilities for each model
yts_pred_v1 = model_1.predict(X_test_tf).reshape(-1, 1)
yts_pred_v2 = model_2.predict(X_test_tf).reshape(-1, 1)
yts_pred_v3 = model_3.predict(X_test_tf).reshape(-1, 1)
# Display metrics for each model
display_metrics(y_test_array, yts_pred_v1, 'Model v1')
display_metrics(y_test_array, yts_pred_v2, 'Model v2')
display_metrics(y_test_array, yts_pred_v3, 'Model v3')
# Out:
# Training set
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 2ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-63481ca8fdcf> in <cell line: 23>()
#      21 ytr_pred_v3 = model_3.predict(X_train_tf).reshape(-1, 1)
#      22 # Display metrics for each model
# ---> 23 display_metrics(y_train_array, ytr_pred_v1, 'Model v1')
#      24 display_metrics(y_train_array, ytr_pred_v2, 'Model v2')
#      25 display_metrics(y_train_array, ytr_pred_v3, 'Model v3')
#
# <ipython-input-103-63481ca8fdcf> in display_metrics(y_true, y_pred, model_name)
#       4     mse = mean_squared_error(y_true, y_pred)
#       5     rmse = np.sqrt(mean_squared_error(y_true, y_pred))
# ----> 6     r2 = r2_score(y_true, y_pred)
#       7
#       8     print(f'Model: {model_name}')
#
# <ipython-input-90-cf9975493958> in r2_score(y_true, y_pred)
#       3 def r2_score(y_true, y_pred):
#       4     SS_res =  K.sum(K.square(y_true - y_pred))
# ----> 5     SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
#       6     return (1 - SS_res / (SS_tot + K.epsilon()))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in mean(x, axis, keepdims)
#    2919         A tensor with the mean of elements of `x`.
#    2920     """
# -> 2921     if x.dtype.base_dtype == tf.bool:
#    2922         x = tf.cast(x, floatx())
#    2923     return tf.reduce_mean(x, axis, keepdims)
#
# AttributeError: 'numpy.dtype[int64]' object has no attribute 'base_dtype'

# %% [markdown]
# ## Model choice:
#
# The best model is the Gradiant Boosting Regressor because it has the highest R2_score and the lowest mean_absolute_error, mean_squared_error and root_mean_squared_error without overfitting.

# %%
# Compare the ground truth and the prediction for the Gradiant Boosting Regressor
plt.figure(figsize=(10, 5))
plt.scatter(y_train, gbr_train_preds, alpha=0.5)
plt.xlabel("Actual Product Weight")
plt.ylabel("Predicted Product Weight")
plt.title("Actual vs. Predicted Product Weight")
plt.show()
